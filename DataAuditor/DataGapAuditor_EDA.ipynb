# %%
import os
import glob 
import pandas as pd
from tqdm import tqdm
import xlsxwriter
import re
import time

import warnings
warnings.filterwarnings("ignore")

# %%
# Allowing the user to select the dataset so we can locate the respective folder:
dataset = input("Enter the dataset to review from the Data Auditor: ")
print("The user would like to use the dataset: ", dataset)
# Out:
# The user would like to use the dataset:  Characteristics

# %%
# Vehicles that we're interested in are being listed here:

# Core Fixed Income	                    12776	P73285
# Core Plus Fixed Income	            12777	P74285 
# Global Quality Value	                12783	P85285
# Strategic Fixed Income	            12811	P121285
# Strategic Fixed Income Opportunities	12812	P126285
# US Small Cap Core	                    12823	P147285

sheet_names = ['P73285', 'P74285', 'P85285', 'P121285', 'P126285', 'P147285']

# %%
# Setting file path. We'll be opening first the Performance folder:
absolute_path = "C:/Users/l.arguello/Downloads/Manulife_DataAuditor/"

file_path = absolute_path + dataset

# %%
# Using glob to get all the Excel file names in the selected folder, to loop through them:

csv_files = glob.glob(os.path.join(file_path, "[!~]*.xlsx")) 
  
file_names = []

# Loop over the list of Excel files: 
for f in tqdm(csv_files, desc="Loading…",ascii=False, ncols=75):

        time.sleep(0.03) 
        # Print the location and filename 
        print('File Name:', f.split("\\")[-1]) 
        # Add each Excel file name to file_names list 
        file_names.append(f.split("\\")[-1])      
 
print("Complete.")
# Out:
# Loading…:   0%|                                     | 0/15 [00:00<?, ?it/s]
# Loading…:  40%|███████████▌                 | 6/15 [00:00<00:00, 27.85it/s]
# File Name: Data_Audit_Report_Albourne_Moatspace_1_2024.xlsx
# File Name: Data_Audit_Report_Alpha_Portfolio_Advisors_1_2024.xlsx
# File Name: Data_Audit_Report_Broadridge_1_2024.xlsx
# File Name: Data_Audit_Report_Callan_Assoc_1_2024.xlsx
# File Name: Data_Audit_Report_Camradata_1_2024.xlsx
# File Name: Data_Audit_Report_eVestment_Alliance_1_2024.xlsx
# Loading…:  80%|██████████████████████▍     | 12/15 [00:00<00:00, 27.43it/s]
# File Name: Data_Audit_Report_Global_Fund_Search_1_2024.xlsx
# File Name: Data_Audit_Report_Global_Manager_Research_1_2024.xlsx
# File Name: Data_Audit_Report_Investment_Metrics_1_2024.xlsx
# File Name: Data_Audit_Report_LCG_Assoc_1_2024.xlsx
# File Name: Data_Audit_Report_Mercer_1_2024.xlsx
# File Name: Data_Audit_Report_Morningstar_1_2024.xlsx
# Loading…: 100%|████████████████████████████| 15/15 [00:00<00:00, 24.31it/s]
# File Name: Data_Audit_Report_Preqin_Hedge_Fund_Analyst_1_2024.xlsx
# File Name: Data_Audit_Report_PSN_Informa_1_2024.xlsx
# File Name: Data_Audit_Report_Wilshire_1_2024.xlsx
# Complete.

# %%
# Loading a sample of the names list obtained from the selected folder:
file_names
# Out:
# ['Data_Audit_Report_Albourne_Moatspace_1_2024.xlsx',
#  'Data_Audit_Report_Alpha_Portfolio_Advisors_1_2024.xlsx',
#  'Data_Audit_Report_Broadridge_1_2024.xlsx',
#  'Data_Audit_Report_Callan_Assoc_1_2024.xlsx',
#  'Data_Audit_Report_Camradata_1_2024.xlsx',
#  'Data_Audit_Report_eVestment_Alliance_1_2024.xlsx',
#  'Data_Audit_Report_Global_Fund_Search_1_2024.xlsx',
#  'Data_Audit_Report_Global_Manager_Research_1_2024.xlsx',
#  'Data_Audit_Report_Investment_Metrics_1_2024.xlsx',
#  'Data_Audit_Report_LCG_Assoc_1_2024.xlsx',
#  'Data_Audit_Report_Mercer_1_2024.xlsx',
#  'Data_Audit_Report_Morningstar_1_2024.xlsx',
#  'Data_Audit_Report_Preqin_Hedge_Fund_Analyst_1_2024.xlsx',
#  'Data_Audit_Report_PSN_Informa_1_2024.xlsx',
#  'Data_Audit_Report_Wilshire_1_2024.xlsx']

# %%
excel_file_content = pd.read_excel(file_path+'/'+file_names[3])

# %%
excel_file_content.iloc[3]
# Out:
# Unnamed: 0                             Firm:
# Unnamed: 1    Manulife Investment Management
# Unnamed: 2                               NaN
# Name: 3, dtype: object

# %%
final_dict = []
nodata_ = []

print('Checking file name: ', file_names[3])
# This variable will contain the first sheet in the Data Audtor (table of contents) which will be needed to fill information in the tables:
excel_file_content = pd.read_excel(file_path+'/'+file_names[3]) 
# For loop to select the sheet name (vehicle):
for j in range(len(sheet_names)):
    # Will do a try and except since there are sheets that don't exist in the files, so the code doesn't crash:
    try:
        print('Checking sheet name: ', sheet_names[3])
        # Defining the Excel file to be openned and the sheet we need from the book:
        excel_file_orig = pd.read_excel(file_path+'/'+file_names[3], sheet_name=sheet_names[3])
    except:
    # If sheet is not found then let's try this so the code can continue:
        print('No sheet found for the vehicle {}'.format(sheet_names[3]))
        dict_ = {'Database': excel_file_content.iloc[4][1],            # Database name e.g. "Wilshire"
                 sheet_names[3]: "No audit data generated.",        # Product/vehicle name with description of findings e.g. "Core Fixed Income Composite (P73285)"
                } 
        nodata_.append(dict_) # Adding the respective database and vehicle name that does not exist to list
        output_df_ = pd.DataFrame(nodata_).groupby(['Database']).sum() # Grouping dataframe by database
        continue
    # Selecting the header names placed in row 7:
    excel_file_orig.rename(columns = excel_file_orig.iloc[7], inplace= True)
    # Selecting the rows with data and reseting the index:
    excel_file = excel_file_orig[7:][1:].set_index(['Date'], drop=True)    
    # We need information from 09/2022 onwards, so I'll be turning Date column into correct type and then filter by date:
    excel_file.index = pd.to_datetime(excel_file.index)
    # Selecting data in the dataframe by the correct date:
    excel_file = excel_file[~(excel_file.index < '09/2022')]
    # Setting up the correct format for the index/Date column
    excel_file.index = excel_file.index.strftime("%m/%Y")
    # Dropping rows and columns in which all the cells contain NaN values:
    excel_file = excel_file.dropna(how='all', axis=0).dropna(how='all', axis=1)
    # Removing commas and $ signs in the numerical values:
    #excel_file = excel_file.replace(, regex=True).replace('Million', '').replace('million', '')
    # Creating a for loop to assign dummy variables to the Data Gap Auditor report:
# Out:
# Checking file name:  Data_Audit_Report_Callan_Assoc_1_2024.xlsx
# Checking sheet name:  P121285
# Checking sheet name:  P121285
# Checking sheet name:  P121285
# Checking sheet name:  P121285
# Checking sheet name:  P121285
# Checking sheet name:  P121285

# %%
for n in range(0, excel_file.shape[1]):
    for m,p in enumerate(excel_file[excel_file.columns[(n)]]):
            # Avoiding code crashes using try/except:    
        try:
            if (int(float(p) >= 0)) or (int(float(p) <= 0)):
                            excel_file[excel_file.columns[n]][m] = '0'  # "Complete"
        except:
            if re.match(r'(-?[0-9\.]+) \s*/ (-?[0-9\.]+)', p):
                  print('aaaaaa')
# Out:
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa
# aaaaaa

# %%
a = excel_file['AA/Aa Current']

# %%
b = a.replace(' %','', regex=True)
b
# Out:
# Date
# 12/2023        0 / <NO DATA>
# 12/2023                  NaN
# 09/2023    <NO APX> / 102.58
# 06/2023                    0
# 03/2023                    0
# 12/2022                    0
# 09/2022                    0
# Name: AA/Aa Current, dtype: object

# %%
b.replace(r'<NO APX> \s*/ (-?[0-9\.]+)','', regex=True)
# Out:
# Date
# 12/2023    0 / <NO DATA>
# 12/2023              NaN
# 09/2023
# 06/2023                0
# 03/2023                0
# 12/2022                0
# 09/2022                0
# Name: AA/Aa Current, dtype: object

# %%
final_dict = []
nodata_ = []

for i in range(len(file_names)):
    print('Checking file name: ', file_names[i])
    # This variable will contain the first sheet in the Data Audtor (table of contents) which will be needed to fill information in the tables:
    excel_file_content = pd.read_excel(file_path+'/'+file_names[i]) 

    # For loop to select the sheet name (vehicle):
    for j in range(len(sheet_names)):
        # Will do a try and except since there are sheets that don't exist in the files, so the code doesn't crash:
        try:
            print('Checking sheet name: ', sheet_names[j])
            # Defining the Excel file to be openned and the sheet we need from the book:
            excel_file_orig = pd.read_excel(file_path+'/'+file_names[i], sheet_name=sheet_names[j])
        except:
        # If sheet is not found then let's try this so the code can continue:
            print('No sheet found for the vehicle {}'.format(sheet_names[j]))
            dict_ = {'Database': excel_file_content.iloc[4][1],            # Database name e.g. "Wilshire"
                     sheet_names[j]: "No audit data generated.",        # Product/vehicle name with description of findings e.g. "Core Fixed Income Composite (P73285)"
                    } 
            nodata_.append(dict_) # Adding the respective database and vehicle name that does not exist to list
            output_df_ = pd.DataFrame(nodata_).groupby(['Database']).sum() # Grouping dataframe by database
            continue

        # Selecting the header names placed in row 7:
        excel_file_orig.rename(columns = excel_file_orig.iloc[7], inplace= True)
        # Selecting the rows with data and reseting the index:
        excel_file = excel_file_orig[7:][1:].set_index(['Date'], drop=True)    
        # We need information from 09/2022 onwards, so I'll be turning Date column into correct type and then filter by date:
        excel_file.index = pd.to_datetime(excel_file.index)
        # Selecting data in the dataframe by the correct date:
        excel_file = excel_file[~(excel_file.index < '09/2022')]
        # Setting up the correct format for the index/Date column
        excel_file.index = excel_file.index.strftime("%m/%Y")
        # Dropping rows and columns in which all the cells contain NaN values:
        excel_file = excel_file.dropna(how='all', axis=0).dropna(how='all', axis=1)
        # Removing commas and $ signs in the numerical values:
        #excel_file = excel_file.replace(, regex=True).replace('Million', '').replace('million', '')

        # Creating a for loop to assign dummy variables to the Data Gap Auditor report:
        for n in range(0, excel_file.shape[1]):
            for m,p in enumerate(excel_file[excel_file.columns[(n)]]):
                    # Avoiding code crashes using try/except:    
                try:
                    if (int(float(p) >= 0)) or (int(float(p) <= 0)):
                                    excel_file[excel_file.columns[n]][m] = '0'  # "Complete"
                except:
                    # APX FILE if (' / <NO DATA>') in p:
                    # APX FILE     excel_file[excel_file.columns[n]][m] = '1'
                    # APX FILE else:
                    # APX FILE    excel_file[excel_file.columns[n]][m] = ''
                     
                    if ('<NO APX> / ') in p:
                         excel_file[excel_file.columns[n]][m] = '2'     # "Data not in the Vault" // Client could want APX to distribute this data for them
                    elif re.match(r'(-?[0-9\.]+) \s*/ (-?[0-9\.]+)', p):
                         excel_file[excel_file.columns[n]][m] = '3'     # "Data not matching" // APX needs to review this data until it matches/is Complete  
                    else:
                         excel_file[excel_file.columns[n]][m] = ''
                     
                        #if (r'(-?[0-9\.]+)\s*/ <NO DATA>') in p:
                        #    excel_file[excel_file.columns[n]][m] = '1' # "Data not in the database" // APX needs to distribute this data
                        #elif "<NO APX> / " in p:
                        #    excel_file[excel_file.columns[n]][m] = excel_file[excel_file.columns[n]][m].replace(p, '2') # "Data not in the Vault" // Client could want APX to distribute this data for them
                        #elif " / " in p:
                        #    excel_file[excel_file.columns[n]][m] = excel_file[excel_file.columns[n]][m].replace(p, '3') # "Data not matching" // APX needs to review this data until it matches/is Complete     
                        #else:
                        #    excel_file[excel_file.columns[n]][m] = ''  # If the cell does not contain any of this criteria above, then it's not relevant for our analysis/review
        #excel_file = excel_file.replace(',','', regex=True).replace(' %','', regex=True).replace('-','', regex=True)
        #excel_file = excel_file.replace({
         #                               r'(-?[0-9\.]+) \s*/ <NO DATA>': '1',                 # Data not in database
         #                               r'[a-zA-Z0-9_.-] \s*/ <NO DATA>': '1',
         #                               '<NO DATA>': '1', 
         #                               r'<NO APX> \s*/ (-?[0-9\.]+)': '2',                 # Data not in Vault
         #                               r'<NO APX> \s*/ [a-zA-Z0-9_.-]': '2',
         #                               '<NO APX>': '2',
         #                               r'(-?[0-9\.]+) \s*/ (-?[0-9\.]+)': '3',              # Data not matching
         #                               ' / ':'0',
         #                               r"[-%()\"#/@$;:<>{}`+=~|.!?,]":''}, regex=True)
        
        for n in range(0, excel_file.shape[1]):
            for m,p in enumerate(excel_file[excel_file.columns[(n)]]):
                
                 if (p != '1') and (p != '2') and (p != '3') and (p != '0'):
                      excel_file[excel_file.columns[n]][m] = ''
                 #if not ('2' in p):
                 #     excel_file[excel_file.columns[n]][m] = ''
                 #if not ('3' in p):
                 #     excel_file[excel_file.columns[n]][m] = ''
                 #if not ('0' in p):
                 #     excel_file[excel_file.columns[n]][m] = ''

            # Let's fill the NaN values for easier further processes:
        excel_file.fillna('', inplace=True)
            # Putting the dummy variables in a single column named 'Review':
        excel_file['Review'] = excel_file[excel_file.columns[0:]].apply(lambda x: ''.join(x.astype(str)), axis=1)

        for m,p in enumerate(excel_file['Review']):


                        #if all('0' in k for k in p):
                        #    excel_file['Review'][m] = excel_file['Review'][m].replace(p, '')

                    #if any('1' in k for k in p):
                    #    excel_file['Review'][m] = excel_file['Review'][m].replace(p, 'Priority 1')          # APX needs to distribute this data

                        #elif (all('1' in k for k in p)):
                        #    excel_file['Review'][m] = excel_file['Review'][m].replace(p, 'Priority 1')     # Data not in the Vault  
                        if any('2' in k for k in p):
                            excel_file['Review'][m] = excel_file['Review'][m].replace(p, 'Priority 2')      # Client could want APX to distribute this data for them

                        elif any('3' in k for k in p):
                            excel_file['Review'][m] = excel_file['Review'][m].replace(p, 'Priority 3')      # Data not matching
                  
                             

        excel_file.to_excel(r'C:\Users\l.arguello\Documents\Python Scripts\APX_automation_reports\output\data_auditor_review\{}_{}_sheet{}.xlsx'.format(file_names[i], dataset, sheet_names[j]))
        #periods_1 = []
        periods_2 = []       
        periods_3 = []
        description = []
        for m,p in enumerate(zip(excel_file['Review'],excel_file.index)):

        #if p[0] == 'Complete':
        #    periods_0.append(p[1])
             
        # APX FILE     if p[0] == 'Priority 1':
        # APX FILE         periods_1.append(p[1])
        # APX FILE     elif periods_1 == periods_1:
        # APX FILE         description.append("".format((list(set(periods_1)))).replace("'",'').replace('[','').replace(']',''))    
        # APX FILE periods_1 = list(set(periods_1))

            if p[0] == 'Priority 2':
                 periods_2.append(p[1])
            if p[0] == 'Priority 3':
                 periods_3.append(p[1])

            elif periods_2 == periods_2:
                 description.append("".format((list(set(periods_2)))).replace("'",'').replace('[','').replace(']',''))    
            elif periods_3 == periods_3:
                 description.append("".format((list(set(periods_3)))).replace("'",'').replace('[','').replace(']',''))  
        periods_2 = list(set(periods_2))
        periods_3 = list(set(periods_3))


            #elif p[0] == 'Priority 2':
            #    periods_2.append(p[1])
            #elif p[0] == 'Priority 3':
            #    periods_3.append(p[1])
        #0 "Complete"
        #1 "Data not in the Vault"
        #2 "Data not in the database"
        #3 "Data not matching"    
        # A description list is created to put in the final review without considering empty period lists:
        # if periods_0 := periods_0: description.append("✔ Complete for the periods: {}\n".format((list(set(periods_0)))).replace("'",'').replace('[','').replace(']',''))
        # if periods_1 := periods_1: description.append("● Priority 1: {}\n".format((list(set(periods_1)))).replace("'",'').replace('[','').replace(']',''))
        if periods_2 := periods_2: description.append("● Priority 2: {}\n".format(list(set((periods_2)))).replace("'",'').replace('[','').replace(']',''))
        if periods_3 := periods_3: description.append("● Priority 3: {}\n".format((list(set(periods_3)))).replace("'",'').replace('[','').replace(']',''))  
        description = list(set(description))

        excel_file_content = pd.read_excel(file_path+'/'+file_names[i]) 
        # Building the dictionary to then transform it into a dataframe:
        dict = {'Database': excel_file_content.iloc[4][1],      # Database name e.g. "Wilshire"
                excel_file_orig.iloc[6][1]: description,        # Product/vehicle name with description of findings e.g. "Core Fixed Income Composite (P73285)
                }  
        # Creating a new dataframe that will sum up the findings in the Data Auditor        
        output_df = pd.DataFrame([dict])
        # Putting each description in a single line (this may duplicate the database name):
        output_df0 = output_df.explode(excel_file_orig.iloc[6][1])
        # Final dict
        final_dict.append(output_df0)
# Out:
# Checking file name:  Data_Audit_Report_Albourne_Moatspace_1_2024.xlsx
# Checking sheet name:  P73285
# No sheet found for the vehicle P73285
# Checking sheet name:  P74285
# No sheet found for the vehicle P74285
# Checking sheet name:  P85285
# No sheet found for the vehicle P85285
# Checking sheet name:  P121285
# No sheet found for the vehicle P121285
# Checking sheet name:  P126285
# No sheet found for the vehicle P126285
# Checking sheet name:  P147285
# No sheet found for the vehicle P147285
# Checking file name:  Data_Audit_Report_Alpha_Portfolio_Advisors_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# No sheet found for the vehicle P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# No sheet found for the vehicle P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_Broadridge_1_2024.xlsx
# Checking sheet name:  P73285
# No sheet found for the vehicle P73285
# Checking sheet name:  P74285
# No sheet found for the vehicle P74285
# Checking sheet name:  P85285
# No sheet found for the vehicle P85285
# Checking sheet name:  P121285
# No sheet found for the vehicle P121285
# Checking sheet name:  P126285
# No sheet found for the vehicle P126285
# Checking sheet name:  P147285
# No sheet found for the vehicle P147285
# Checking file name:  Data_Audit_Report_Callan_Assoc_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_Camradata_1_2024.xlsx
# Checking sheet name:  P73285
# No sheet found for the vehicle P73285
# Checking sheet name:  P74285
# No sheet found for the vehicle P74285
# Checking sheet name:  P85285
# No sheet found for the vehicle P85285
# Checking sheet name:  P121285
# No sheet found for the vehicle P121285
# Checking sheet name:  P126285
# No sheet found for the vehicle P126285
# Checking sheet name:  P147285
# No sheet found for the vehicle P147285
# Checking file name:  Data_Audit_Report_eVestment_Alliance_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_Global_Fund_Search_1_2024.xlsx
# Checking sheet name:  P73285
# No sheet found for the vehicle P73285
# Checking sheet name:  P74285
# No sheet found for the vehicle P74285
# Checking sheet name:  P85285
# No sheet found for the vehicle P85285
# Checking sheet name:  P121285
# No sheet found for the vehicle P121285
# Checking sheet name:  P126285
# No sheet found for the vehicle P126285
# Checking sheet name:  P147285
# No sheet found for the vehicle P147285
# Checking file name:  Data_Audit_Report_Global_Manager_Research_1_2024.xlsx
# Checking sheet name:  P73285
# No sheet found for the vehicle P73285
# Checking sheet name:  P74285
# No sheet found for the vehicle P74285
# Checking sheet name:  P85285
# No sheet found for the vehicle P85285
# Checking sheet name:  P121285
# No sheet found for the vehicle P121285
# Checking sheet name:  P126285
# No sheet found for the vehicle P126285
# Checking sheet name:  P147285
# No sheet found for the vehicle P147285
# Checking file name:  Data_Audit_Report_Investment_Metrics_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_LCG_Assoc_1_2024.xlsx
# Checking sheet name:  P73285
# No sheet found for the vehicle P73285
# Checking sheet name:  P74285
# No sheet found for the vehicle P74285
# Checking sheet name:  P85285
# No sheet found for the vehicle P85285
# Checking sheet name:  P121285
# No sheet found for the vehicle P121285
# Checking sheet name:  P126285
# No sheet found for the vehicle P126285
# Checking sheet name:  P147285
# No sheet found for the vehicle P147285
# Checking file name:  Data_Audit_Report_Mercer_1_2024.xlsx
# Checking sheet name:  P73285
# No sheet found for the vehicle P73285
# Checking sheet name:  P74285
# No sheet found for the vehicle P74285
# Checking sheet name:  P85285
# No sheet found for the vehicle P85285
# Checking sheet name:  P121285
# No sheet found for the vehicle P121285
# Checking sheet name:  P126285
# No sheet found for the vehicle P126285
# Checking sheet name:  P147285
# No sheet found for the vehicle P147285
# Checking file name:  Data_Audit_Report_Morningstar_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# No sheet found for the vehicle P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# No sheet found for the vehicle P147285
# Checking file name:  Data_Audit_Report_Preqin_Hedge_Fund_Analyst_1_2024.xlsx
# Checking sheet name:  P73285
# No sheet found for the vehicle P73285
# Checking sheet name:  P74285
# No sheet found for the vehicle P74285
# Checking sheet name:  P85285
# No sheet found for the vehicle P85285
# Checking sheet name:  P121285
# No sheet found for the vehicle P121285
# Checking sheet name:  P126285
# No sheet found for the vehicle P126285
# Checking sheet name:  P147285
# No sheet found for the vehicle P147285
# Checking file name:  Data_Audit_Report_PSN_Informa_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_Wilshire_1_2024.xlsx
# Checking sheet name:  P73285
# No sheet found for the vehicle P73285
# Checking sheet name:  P74285
# No sheet found for the vehicle P74285
# Checking sheet name:  P85285
# No sheet found for the vehicle P85285
# Checking sheet name:  P121285
# No sheet found for the vehicle P121285
# Checking sheet name:  P126285
# No sheet found for the vehicle P126285
# Checking sheet name:  P147285
# No sheet found for the vehicle P147285

# %%
import re
string='23.34 / 34.45 %'
if re.match(r'[a-zA-Z-_.-]', string):
    print(string.replace(string, 'a1'))
else:
    print(string.replace(string, 'a0'))
# Out:
# a0

# %%
string.replace('%', '')
# Out:
# '23.34 / 34.45 '

# %%
a = pd.concat(final_dict)
a = a.reindex(sorted(a.columns), axis=1)
a.set_index("Database", drop=True, inplace=True)
a
# Out:
#                                        Core Fixed Income Composite (P73285)  \
# Database
# Alpha Portfolio Advisors
# Alpha Portfolio Advisors                            ● Priority 2: 12/2022\n
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Callan Assoc.
# Callan Assoc.             ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# Investment Metrics
# Investment Metrics        ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Morningstar
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# PSN Informa
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
#
#                                   Core Plus Fixed Income Composite (P74285)  \
# Database
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.
# Callan Assoc.             ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance
# eVestment Alliance        ● Priority 2: 12/2022, 06/2023, 09/2022, 09/20...
# eVestment Alliance                                  ● Priority 3: 03/2023\n
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics
# Investment Metrics        ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Morningstar                                                             NaN
# Morningstar
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
#
#                                     Global Quality Value Composite (P85285)  \
# Database
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors
# Alpha Portfolio Advisors                            ● Priority 2: 12/2022\n
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.
# Callan Assoc.                     ● Priority 2: 12/2022, 09/2022, 09/2023\n
# Callan Assoc.                              ● Priority 3: 03/2023, 06/2023\n
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance
# eVestment Alliance        ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics
# Investment Metrics                         ● Priority 2: 12/2022, 09/2022\n
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
#
#                                  Strategic Fixed Income Composite (P121285)  \
# Database
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors
# Alpha Portfolio Advisors                            ● Priority 2: 12/2022\n
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.
# Callan Assoc.             ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance
# eVestment Alliance                ● Priority 2: 12/2022, 09/2022, 06/2023\n
# eVestment Alliance                                  ● Priority 3: 03/2023\n
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics
# Investment Metrics        ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# Morningstar
# Morningstar                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
#
#                          Strategic Fixed Income Opportunities Composite (P126285)  \
# Database
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.
# Callan Assoc.             ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance
# eVestment Alliance                         ● Priority 2: 12/2022, 09/2022\n
# eVestment Alliance                         ● Priority 3: 03/2023, 06/2023\n
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics
# Investment Metrics        ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# Morningstar
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
#
#                                      U.S Small-Cap Core Composite (P147285)
# Database
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors                                                NaN
# Alpha Portfolio Advisors
# Alpha Portfolio Advisors                            ● Priority 2: 12/2022\n
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.                                                           NaN
# Callan Assoc.
# Callan Assoc.                     ● Priority 2: 03/2023, 09/2022, 09/2023\n
# Callan Assoc.                              ● Priority 3: 12/2022, 06/2023\n
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance                                                      NaN
# eVestment Alliance
# eVestment Alliance        ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics                                                      NaN
# Investment Metrics
# Investment Metrics        ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# Morningstar                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa                                                             NaN
# PSN Informa

# %%
output_df_
# Out:
#                                              P73285                    P74285  \
# Database
# Albourne Moatspace         No audit data generated.  No audit data generated.
# Alpha Portfolio Advisors                          0  No audit data generated.
# Broadridge                 No audit data generated.  No audit data generated.
# Camradata                  No audit data generated.  No audit data generated.
# Global Fund Search         No audit data generated.  No audit data generated.
# Global Manager Research    No audit data generated.  No audit data generated.
# LCG Assoc.                 No audit data generated.  No audit data generated.
# Mercer                     No audit data generated.  No audit data generated.
# Morningstar                                       0                         0
# Preqin Hedge Fund Analyst  No audit data generated.  No audit data generated.
# Wilshire                   No audit data generated.  No audit data generated.
#
#                                              P85285                   P121285  \
# Database
# Albourne Moatspace         No audit data generated.  No audit data generated.
# Alpha Portfolio Advisors                          0                         0
# Broadridge                 No audit data generated.  No audit data generated.
# Camradata                  No audit data generated.  No audit data generated.
# Global Fund Search         No audit data generated.  No audit data generated.
# Global Manager Research    No audit data generated.  No audit data generated.
# LCG Assoc.                 No audit data generated.  No audit data generated.
# Mercer                     No audit data generated.  No audit data generated.
# Morningstar                No audit data generated.                         0
# Preqin Hedge Fund Analyst  No audit data generated.  No audit data generated.
# Wilshire                   No audit data generated.  No audit data generated.
#
#                                             P126285                   P147285
# Database
# Albourne Moatspace         No audit data generated.  No audit data generated.
# Alpha Portfolio Advisors   No audit data generated.                         0
# Broadridge                 No audit data generated.  No audit data generated.
# Camradata                  No audit data generated.  No audit data generated.
# Global Fund Search         No audit data generated.  No audit data generated.
# Global Manager Research    No audit data generated.  No audit data generated.
# LCG Assoc.                 No audit data generated.  No audit data generated.
# Mercer                     No audit data generated.  No audit data generated.
# Morningstar                                       0  No audit data generated.
# Preqin Hedge Fund Analyst  No audit data generated.  No audit data generated.
# Wilshire                   No audit data generated.  No audit data generated.

# %%
for col1 in output_df_.columns:
    for col2 in a.columns:
        if col1 in col2:
            output_df_.columns = a.columns

# %%
output_df_
# Out:
#                           Core Fixed Income Composite (P73285)  \
# Database
# Albourne Moatspace                    No audit data generated.
# Alpha Portfolio Advisors                                     0
# Broadridge                            No audit data generated.
# Camradata                             No audit data generated.
# Global Fund Search                    No audit data generated.
# Global Manager Research               No audit data generated.
# LCG Assoc.                            No audit data generated.
# Mercer                                No audit data generated.
# Morningstar                                                  0
# Preqin Hedge Fund Analyst             No audit data generated.
# Wilshire                              No audit data generated.
#
#                           Core Plus Fixed Income Composite (P74285)  \
# Database
# Albourne Moatspace                         No audit data generated.
# Alpha Portfolio Advisors                   No audit data generated.
# Broadridge                                 No audit data generated.
# Camradata                                  No audit data generated.
# Global Fund Search                         No audit data generated.
# Global Manager Research                    No audit data generated.
# LCG Assoc.                                 No audit data generated.
# Mercer                                     No audit data generated.
# Morningstar                                                       0
# Preqin Hedge Fund Analyst                  No audit data generated.
# Wilshire                                   No audit data generated.
#
#                           Global Quality Value Composite (P85285)  \
# Database
# Albourne Moatspace                       No audit data generated.
# Alpha Portfolio Advisors                                        0
# Broadridge                               No audit data generated.
# Camradata                                No audit data generated.
# Global Fund Search                       No audit data generated.
# Global Manager Research                  No audit data generated.
# LCG Assoc.                               No audit data generated.
# Mercer                                   No audit data generated.
# Morningstar                              No audit data generated.
# Preqin Hedge Fund Analyst                No audit data generated.
# Wilshire                                 No audit data generated.
#
#                           Strategic Fixed Income Composite (P121285)  \
# Database
# Albourne Moatspace                          No audit data generated.
# Alpha Portfolio Advisors                                           0
# Broadridge                                  No audit data generated.
# Camradata                                   No audit data generated.
# Global Fund Search                          No audit data generated.
# Global Manager Research                     No audit data generated.
# LCG Assoc.                                  No audit data generated.
# Mercer                                      No audit data generated.
# Morningstar                                                        0
# Preqin Hedge Fund Analyst                   No audit data generated.
# Wilshire                                    No audit data generated.
#
#                           Strategic Fixed Income Opportunities Composite (P126285)  \
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors                            No audit data generated.
# Broadridge                                          No audit data generated.
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar                                                                0
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
#
#                           U.S Small-Cap Core Composite (P147285)
# Database
# Albourne Moatspace                      No audit data generated.
# Alpha Portfolio Advisors                                       0
# Broadridge                              No audit data generated.
# Camradata                               No audit data generated.
# Global Fund Search                      No audit data generated.
# Global Manager Research                 No audit data generated.
# LCG Assoc.                              No audit data generated.
# Mercer                                  No audit data generated.
# Morningstar                             No audit data generated.
# Preqin Hedge Fund Analyst               No audit data generated.
# Wilshire                                No audit data generated.

# %%
review_file = pd.merge(a, output_df_, on='Database', how='outer').groupby('Database').sum()

# %%
review_file
# Out:
#                                       Core Fixed Income Composite (P73285)_x  \
# Database
# Albourne Moatspace                                                         0
# Alpha Portfolio Advisors                             ● Priority 2: 12/2022\n
# Broadridge                                                                 0
# Callan Assoc.              ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Camradata                                                                  0
# Global Fund Search                                                         0
# Global Manager Research                                                    0
# Investment Metrics         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# LCG Assoc.                                                                 0
# Mercer                                                                     0
# Morningstar
# PSN Informa
# Preqin Hedge Fund Analyst                                                  0
# Wilshire                                                                   0
# eVestment Alliance                                                         0
#
#                                  Core Plus Fixed Income Composite (P74285)_x  \
# Database
# Albourne Moatspace                                                         0
# Alpha Portfolio Advisors                                                   0
# Broadridge                                                                 0
# Callan Assoc.              ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Camradata                                                                  0
# Global Fund Search                                                         0
# Global Manager Research                                                    0
# Investment Metrics         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# LCG Assoc.                                                                 0
# Mercer                                                                     0
# Morningstar
# PSN Informa
# Preqin Hedge Fund Analyst                                                  0
# Wilshire                                                                   0
# eVestment Alliance         ● Priority 2: 12/2022, 06/2023, 09/2022, 09/20...
#
#                                    Global Quality Value Composite (P85285)_x  \
# Database
# Albourne Moatspace                                                         0
# Alpha Portfolio Advisors                             ● Priority 2: 12/2022\n
# Broadridge                                                                 0
# Callan Assoc.              ● Priority 2: 12/2022, 09/2022, 09/2023\n● Pri...
# Camradata                                                                  0
# Global Fund Search                                                         0
# Global Manager Research                                                    0
# Investment Metrics                          ● Priority 2: 12/2022, 09/2022\n
# LCG Assoc.                                                                 0
# Mercer                                                                     0
# Morningstar                                                                0
# PSN Informa                                                                0
# Preqin Hedge Fund Analyst                                                  0
# Wilshire                                                                   0
# eVestment Alliance         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
#
#                                 Strategic Fixed Income Composite (P121285)_x  \
# Database
# Albourne Moatspace                                                         0
# Alpha Portfolio Advisors                             ● Priority 2: 12/2022\n
# Broadridge                                                                 0
# Callan Assoc.              ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Camradata                                                                  0
# Global Fund Search                                                         0
# Global Manager Research                                                    0
# Investment Metrics         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# LCG Assoc.                                                                 0
# Mercer                                                                     0
# Morningstar
# PSN Informa                                                                0
# Preqin Hedge Fund Analyst                                                  0
# Wilshire                                                                   0
# eVestment Alliance         ● Priority 2: 12/2022, 09/2022, 06/2023\n● Pri...
#
#                           Strategic Fixed Income Opportunities Composite (P126285)_x  \
# Database
# Albourne Moatspace                                                         0
# Alpha Portfolio Advisors                                                   0
# Broadridge                                                                 0
# Callan Assoc.              ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Camradata                                                                  0
# Global Fund Search                                                         0
# Global Manager Research                                                    0
# Investment Metrics         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# LCG Assoc.                                                                 0
# Mercer                                                                     0
# Morningstar
# PSN Informa                                                                0
# Preqin Hedge Fund Analyst                                                  0
# Wilshire                                                                   0
# eVestment Alliance         ● Priority 2: 12/2022, 09/2022\n● Priority 3: ...
#
#                                     U.S Small-Cap Core Composite (P147285)_x  \
# Database
# Albourne Moatspace                                                         0
# Alpha Portfolio Advisors                             ● Priority 2: 12/2022\n
# Broadridge                                                                 0
# Callan Assoc.              ● Priority 2: 03/2023, 09/2022, 09/2023\n● Pri...
# Camradata                                                                  0
# Global Fund Search                                                         0
# Global Manager Research                                                    0
# Investment Metrics         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# LCG Assoc.                                                                 0
# Mercer                                                                     0
# Morningstar                                                                0
# PSN Informa
# Preqin Hedge Fund Analyst                                                  0
# Wilshire                                                                   0
# eVestment Alliance         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
#
#                           Core Fixed Income Composite (P73285)_y  \
# Database
# Albourne Moatspace                      No audit data generated.
# Alpha Portfolio Advisors                                       0
# Broadridge                              No audit data generated.
# Callan Assoc.                                                  0
# Camradata                               No audit data generated.
# Global Fund Search                      No audit data generated.
# Global Manager Research                 No audit data generated.
# Investment Metrics                                             0
# LCG Assoc.                              No audit data generated.
# Mercer                                  No audit data generated.
# Morningstar                                                    0
# PSN Informa                                                    0
# Preqin Hedge Fund Analyst               No audit data generated.
# Wilshire                                No audit data generated.
# eVestment Alliance                                             0
#
#                                  Core Plus Fixed Income Composite (P74285)_y  \
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors   No audit data generated.No audit data generate...
# Broadridge                                          No audit data generated.
# Callan Assoc.                                                              0
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Investment Metrics                                                         0
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar                                                                0
# PSN Informa                                                                0
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
# eVestment Alliance                                                         0
#
#                                    Global Quality Value Composite (P85285)_y  \
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors                                                   0
# Broadridge                                          No audit data generated.
# Callan Assoc.                                                              0
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Investment Metrics                                                         0
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar                No audit data generated.No audit data generate...
# PSN Informa                                                                0
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
# eVestment Alliance                                                         0
#
#                           Strategic Fixed Income Composite (P121285)_y  \
# Database
# Albourne Moatspace                            No audit data generated.
# Alpha Portfolio Advisors                                             0
# Broadridge                                    No audit data generated.
# Callan Assoc.                                                        0
# Camradata                                     No audit data generated.
# Global Fund Search                            No audit data generated.
# Global Manager Research                       No audit data generated.
# Investment Metrics                                                   0
# LCG Assoc.                                    No audit data generated.
# Mercer                                        No audit data generated.
# Morningstar                                                          0
# PSN Informa                                                          0
# Preqin Hedge Fund Analyst                     No audit data generated.
# Wilshire                                      No audit data generated.
# eVestment Alliance                                                   0
#
#                           Strategic Fixed Income Opportunities Composite (P126285)_y  \
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors   No audit data generated.No audit data generate...
# Broadridge                                          No audit data generated.
# Callan Assoc.                                                              0
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Investment Metrics                                                         0
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar                                                                0
# PSN Informa                                                                0
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
# eVestment Alliance                                                         0
#
#                                     U.S Small-Cap Core Composite (P147285)_y
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors                                                   0
# Broadridge                                          No audit data generated.
# Callan Assoc.                                                              0
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Investment Metrics                                                         0
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar                No audit data generated.No audit data generate...
# PSN Informa                                                                0
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
# eVestment Alliance                                                         0

# %%
review_file.columns = review_file.columns.str.rstrip("_x")
review_file = review_file.drop([x for x in review_file if x.endswith('_y')], axis = 1)
review_file = review_file.replace(0, "No audit data generated.", regex=True)
review_file
# Out:
#                                         Core Fixed Income Composite (P73285)  \
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors                             ● Priority 2: 12/2022\n
# Broadridge                                          No audit data generated.
# Callan Assoc.              ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Investment Metrics         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar
# PSN Informa
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
# eVestment Alliance                                  No audit data generated.
#
#                                    Core Plus Fixed Income Composite (P74285)  \
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors                            No audit data generated.
# Broadridge                                          No audit data generated.
# Callan Assoc.              ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Investment Metrics         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar
# PSN Informa
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
# eVestment Alliance         ● Priority 2: 12/2022, 06/2023, 09/2022, 09/20...
#
#                                      Global Quality Value Composite (P85285)  \
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors                             ● Priority 2: 12/2022\n
# Broadridge                                          No audit data generated.
# Callan Assoc.              ● Priority 2: 12/2022, 09/2022, 09/2023\n● Pri...
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Investment Metrics                          ● Priority 2: 12/2022, 09/2022\n
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar                                         No audit data generated.
# PSN Informa                                         No audit data generated.
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
# eVestment Alliance         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
#
#                                   Strategic Fixed Income Composite (P121285)  \
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors                             ● Priority 2: 12/2022\n
# Broadridge                                          No audit data generated.
# Callan Assoc.              ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Investment Metrics         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar
# PSN Informa                                         No audit data generated.
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
# eVestment Alliance         ● Priority 2: 12/2022, 09/2022, 06/2023\n● Pri...
#
#                           Strategic Fixed Income Opportunities Composite (P126285)  \
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors                            No audit data generated.
# Broadridge                                          No audit data generated.
# Callan Assoc.              ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Investment Metrics         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar
# PSN Informa                                         No audit data generated.
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
# eVestment Alliance         ● Priority 2: 12/2022, 09/2022\n● Priority 3: ...
#
#                                       U.S Small-Cap Core Composite (P147285)
# Database
# Albourne Moatspace                                  No audit data generated.
# Alpha Portfolio Advisors                             ● Priority 2: 12/2022\n
# Broadridge                                          No audit data generated.
# Callan Assoc.              ● Priority 2: 03/2023, 09/2022, 09/2023\n● Pri...
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Investment Metrics         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...
# LCG Assoc.                                          No audit data generated.
# Mercer                                              No audit data generated.
# Morningstar                                         No audit data generated.
# PSN Informa
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                                            No audit data generated.
# eVestment Alliance         ● Priority 2: 12/2022, 06/2023, 03/2023, 09/20...

# %% [markdown]
# Checking for the unique values in each of the columns, since they're not numeric, to start the data cleaning:

# %%
pd.options.display.max_rows = 999

# %%
for col in excel_file:
    print(excel_file[col].unique())
# Out:
# [nan '0 / <NO DATA>' '94.80 / <NO DATA>' '16.37 / <NO DATA>'
#  '8.62 / <NO DATA>' '100 / <NO DATA>']
# [nan '0 / <NO DATA>' '100 / <NO DATA>' '73.00 / <NO DATA>'
#  '2.05 / <NO DATA>' '15.02 / <NO DATA>']
# [nan '2.93 / <NO DATA>' '0 / <NO DATA>' '19.92 / <NO DATA>'
#  '13.49 / <NO DATA>' '1.10 / <NO DATA>' '100 / <NO DATA>']
# [nan '4081.00 / <NO DATA>' '0 / <NO DATA>' '100 / <NO DATA>'
#  '11.47 / <NO DATA>' '14.73 / <NO DATA>' '2.39 / <NO DATA>']
# ['0 / <NO DATA>' nan '3260.00 / <NO DATA>' '2.15 / <NO DATA>'
#  '22.71 / <NO DATA>' '4.54 / <NO DATA>' '100 / <NO DATA>']
# ['0 / <NO DATA>' nan '96.52 / <NO DATA>' '66.68 / <NO DATA>'
#  '100 / <NO DATA>' '7.38 / <NO DATA>' '4.89 / <NO DATA>']
# ['0 / <NO DATA>' nan '95.19 / <NO DATA>' '10.76 / <NO DATA>'
#  '8.76 / <NO DATA>' '100 / <NO DATA>']
# ['0 / <NO DATA>' nan '100 / <NO DATA>' '76.00 / <NO DATA>'
#  '4.02 / <NO DATA>' '14.95 / <NO DATA>']
# ['0 / <NO DATA>' nan '3.48 / <NO DATA>' '18.20 / <NO DATA>'
#  '4.76 / <NO DATA>' '0.83 / <NO DATA>' '100 / <NO DATA>']
# ['0 / <NO DATA>' nan '3939.00 / <NO DATA>' '100 / <NO DATA>'
#  '-0.01 / <NO DATA>' '15.64 / <NO DATA>' '3.13 / <NO DATA>']
# ['0 / <NO DATA>' '3.35 / <NO DATA>' nan '3023.00 / <NO DATA>'
#  '24.79 / <NO DATA>' '3.10 / <NO DATA>' '100 / <NO DATA>']
# ['0 / <NO DATA>' '3.71 / <NO DATA>' nan '94.06 / <NO DATA>'
#  '0.93 / <NO DATA>' '100 / <NO DATA>' '7.50 / <NO DATA>'
#  '4.08 / <NO DATA>']
# ['0 / <NO DATA>' '2.91 / <NO DATA>' nan '43.38 / <NO DATA>'
#  '9.36 / <NO DATA>' '9.88 / <NO DATA>' '100 / <NO DATA>']
# ['0 / <NO DATA>' '7.96 / <NO DATA>' nan '100 / <NO DATA>'
#  '2.08 / <NO DATA>' '4.05 / <NO DATA>' '16.83 / <NO DATA>']
# ['0 / <NO DATA>' '18.23 / <NO DATA>' nan '5.94 / <NO DATA>'
#  '11.98 / <NO DATA>' '2.30 / <NO DATA>' '0.82 / <NO DATA>'
#  '100 / <NO DATA>']
# [nan '0 / <NO DATA>' '0.92 / <NO DATA>' '3675.00 / <NO DATA>'
#  '100 / <NO DATA>' '13.35 / <NO DATA>' '0.00 / <NO DATA>'
#  '16.41 / <NO DATA>']
# ['100 / <NO DATA>' '0 / <NO DATA>' '12.73 / <NO DATA>' '3.77 / <NO DATA>'
#  nan '2761.00 / <NO DATA>' '2.53 / <NO DATA>' '24.19 / <NO DATA>']
# [nan '0 / <NO DATA>' '22.87 / <NO DATA>' '4.05 / <NO DATA>'
#  '100 / <NO DATA>' '68.16 / <NO DATA>' '0.69 / <NO DATA>'
#  '7.78 / <NO DATA>']
# [nan '100 / <NO DATA>' '0 / <NO DATA>' '6.96 / <NO DATA>'
#  '1.09 / <NO DATA>' '94.77 / <NO DATA>' '41.17 / <NO DATA>'
#  '10.36 / <NO DATA>']
# [nan '9.19 / <NO DATA>' '0 / <NO DATA>' '9.59 / <NO DATA>'
#  '100 / <NO DATA>' '82.00 / <NO DATA>' '2.55 / <NO DATA>'
#  '3.01 / <NO DATA>']
# [nan '100 / <NO DATA>' '5.28 / <NO DATA>' '0 / <NO DATA>'
#  '22.18 / <NO DATA>' '16.28 / <NO DATA>' '14.94 / <NO DATA>'
#  '0.42 / <NO DATA>']
# [nan '5.88 / <NO DATA>' '0 / <NO DATA>' '0.92 / <NO DATA>'
#  '100 / <NO DATA>' '15.82 / <NO DATA>' '-0.01 / <NO DATA>']
# [nan '0.01 / <NO DATA>' '0 / <NO DATA>' '14.05 / <NO DATA>'
#  '3.45 / <NO DATA>' '1.82 / <NO DATA>' '100 / <NO DATA>']
# [nan '0 / <NO DATA>' '21.13 / <NO DATA>' '5.20 / <NO DATA>'
#  '95.24 / <NO DATA>' '63.70 / <NO DATA>' '0.67 / <NO DATA>'
#  '100 / <NO DATA>']
# [nan '0.99 / <NO DATA>' '100 / <NO DATA>' '0 / <NO DATA>'
#  '6.18 / <NO DATA>' '1.09 / <NO DATA>' '94.62 / <NO DATA>'
#  '25.92 / <NO DATA>']
# [nan '9.17 / <NO DATA>' '8.71 / <NO DATA>' '0 / <NO DATA>'
#  '8.40 / <NO DATA>' '100 / <NO DATA>' '84.00 / <NO DATA>'
#  '2.79 / <NO DATA>']
# [nan '2.03 / <NO DATA>' '100 / <NO DATA>' '5.39 / <NO DATA>'
#  '0 / <NO DATA>' '20.08 / <NO DATA>' '4.76 / <NO DATA>'
#  '15.76 / <NO DATA>' '16.92 / <NO DATA>']
# [nan '15.52 / <NO DATA>' '2.93 / <NO DATA>' '0 / <NO DATA>'
#  '1.08 / <NO DATA>' '3216.00 / <NO DATA>' '100 / <NO DATA>'
#  '20.99 / <NO DATA>']
# [nan '16.37 / <NO DATA>' '0.01 / <NO DATA>' '0 / <NO DATA>'
#  '14.62 / <NO DATA>' '3.09 / <NO DATA>' '2547.00 / <NO DATA>'
#  '4.18 / <NO DATA>' '100 / <NO DATA>']
# [nan '4.58 / <NO DATA>' '0 / <NO DATA>' '20.96 / <NO DATA>'
#  '5.30 / <NO DATA>' '97.70 / <NO DATA>' '65.96 / <NO DATA>'
#  '100 / <NO DATA>']
# ['100 / <NO DATA>' nan '62.07 / <NO DATA>' '0.98 / <NO DATA>'
#  '0 / <NO DATA>' '7.86 / <NO DATA>' '2.57 / <NO DATA>' '94.49 / <NO DATA>']
# ['0 / <NO DATA>' nan '95.39 / <NO DATA>' '20.69 / <NO DATA>'
#  '8.51 / <NO DATA>' '8.94 / <NO DATA>' '100 / <NO DATA>'
#  '87.00 / <NO DATA>']
# ['0 / <NO DATA>' '100 / <NO DATA>' nan '77.00 / <NO DATA>'
#  '2.14 / <NO DATA>' '5.26 / <NO DATA>' '17.01 / <NO DATA>'
#  '2.30 / <NO DATA>' '16.62 / <NO DATA>']
# [nan '0 / <NO DATA>' '19.21 / <NO DATA>' '16.60 / <NO DATA>'
#  '3.48 / <NO DATA>' '1.03 / <NO DATA>' '3662.00 / <NO DATA>'
#  '100 / <NO DATA>']
# [nan '0 / <NO DATA>' '100 / <NO DATA>' '14.72 / <NO DATA>'
#  '0.01 / <NO DATA>' '14.15 / <NO DATA>' '2874.00 / <NO DATA>']
# [nan '0 / <NO DATA>' '4.76 / <NO DATA>' '19.74 / <NO DATA>'
#  '99.58 / <NO DATA>' '100 / <NO DATA>']
# [nan '0 / <NO DATA>' '94.12 / <NO DATA>' '57.59 / <NO DATA>'
#  '0.92 / <NO DATA>' '100 / <NO DATA>' '6.11 / <NO DATA>']
# [nan '0 / <NO DATA>' '95.06 / <NO DATA>' '20.32 / <NO DATA>'
#  '10.68 / <NO DATA>' '100 / <NO DATA>']
# [nan '0 / <NO DATA>' '100 / <NO DATA>' '77.00 / <NO DATA>'
#  '2.13 / <NO DATA>' '5.42 / <NO DATA>' '0.42 / <NO DATA>']
# [nan '5.88 / <NO DATA>' '0 / <NO DATA>' '20.62 / <NO DATA>'
#  '15.33 / <NO DATA>' '5.94 / <NO DATA>' '3707.00 / <NO DATA>'
#  '100 / <NO DATA>']
# [nan '4006.00 / <NO DATA>' '0 / <NO DATA>' '100 / <NO DATA>'
#  '58.21 / <NO DATA>' '13.63 / <NO DATA>' '0.02 / <NO DATA>'
#  '2.53 / <NO DATA>' '3056.00 / <NO DATA>']
# [nan '3211.00 / <NO DATA>' '0 / <NO DATA>' '3.36 / <NO DATA>'
#  '4.08 / <NO DATA>' '100 / <NO DATA>']
# [nan '0 / <NO DATA>' '97.07 / <NO DATA>' '57.01 / <NO DATA>'
#  '1.01 / <NO DATA>' '100 / <NO DATA>' '4.30 / <NO DATA>']

# %%
pd.concat(final_dict)
# Out:
#                    Database  \
# 0  Alpha Portfolio Advisors
# 0  Alpha Portfolio Advisors
# 0  Alpha Portfolio Advisors
# 0  Alpha Portfolio Advisors
# 0             Callan Assoc.
# 0             Callan Assoc.
# 0             Callan Assoc.
# 0             Callan Assoc.
# 0             Callan Assoc.
# 0             Callan Assoc.
# 0             Callan Assoc.
# 0             Callan Assoc.
# 0             Callan Assoc.
# 0             Callan Assoc.
# 0        eVestment Alliance
# 0        eVestment Alliance
# 0        eVestment Alliance
# 0        eVestment Alliance
# 0        eVestment Alliance
# 0        eVestment Alliance
# 0        eVestment Alliance
# 0        eVestment Alliance
# 0        eVestment Alliance
# 0        eVestment Alliance
# 0        eVestment Alliance
# 0        Investment Metrics
# 0        Investment Metrics
# 0        Investment Metrics
# 0        Investment Metrics
# 0        Investment Metrics
# 0        Investment Metrics
# 0        Investment Metrics
# 0        Investment Metrics
# 0               Morningstar
# 0               Morningstar
# 0               Morningstar
# 0               Morningstar
# 0               PSN Informa
# 0               PSN Informa
# 0               PSN Informa
# 0               PSN Informa
# 0               PSN Informa
# 0               PSN Informa
#
#                 Core Fixed Income Composite (P73285)  \
# 0                            ● Priority 1: 12/2022\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0          ● Priority 1: 12/2023, 12/2022, 09/2022\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  ● Priority 1: 12/2023, 12/2022, 09/2023, 03/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                   ● Priority 1: 06/2023, 09/2023\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  ● Priority 1: 12/2023, 07/2023, 12/2022, 11/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#              Global Quality Value Composite (P85285)  \
# 0                                                NaN
# 0
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0  ● Priority 1: 12/2023, 03/2023, 06/2023, 12/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0                            ● Priority 1: 12/2023\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0  ● Priority 1: 12/2023, 03/2023, 06/2023, 09/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#           Strategic Fixed Income Composite (P121285)  \
# 0                                                NaN
# 0                                                NaN
# 0
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  ● Priority 1: 12/2023, 12/2022, 09/2023, 03/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0          ● Priority 1: 12/2023, 12/2022, 09/2022\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  ● Priority 1: 12/2023, 12/2022, 09/2023, 03/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                   ● Priority 1: 06/2023, 09/2023\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#               U.S Small-Cap Core Composite (P147285)  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0          ● Priority 1: 12/2023, 06/2023, 09/2022\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0                   ● Priority 1: 12/2023, 12/2022\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0                            ● Priority 1: 12/2023\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  ● Priority 1: 12/2023, 07/2023, 12/2022, 11/20...
#
#            Core Plus Fixed Income Composite (P74285)  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0          ● Priority 1: 12/2023, 12/2022, 09/2022\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0  ● Priority 1: 12/2023, 12/2022, 09/2023, 09/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  ● Priority 1: 12/2023, 12/2022, 09/2023, 03/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                   ● Priority 1: 06/2023, 09/2023\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  ● Priority 1: 12/2023, 07/2023, 12/2022, 11/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   Strategic Fixed Income Opportunities Composite (P126285)
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  ● Priority 1: 12/2023, 12/2022, 09/2023, 03/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0
# 0          ● Priority 1: 12/2023, 12/2022, 09/2022\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  ● Priority 1: 12/2023, 12/2022, 09/2023, 03/20...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0          ● Priority 1: 06/2023, 09/2023, 12/2022\n
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN

# %%
###############
# Transforming into a dataframe the last dictionary with the review description:
final_dict_ = pd.concat(final_dict) 
    # final_dict_ has a numerical index, whilst output_df_ has databases as its index, so we'll arrange that:
final_dict_.set_index("Database", drop=True, inplace=True)
final_dict = pd.DataFrame(final_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 6
#       4     # final_dict_ has a numerical index, whilst output_df_ has databases as its index, so we'll arrange that:
#       5 final_dict_.set_index("Database", drop=True, inplace=True)
# ----> 6 final_dict = pd.DataFrame(final_dict)
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\frame.py:822, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     814         mgr = arrays_to_mgr(
#     815             arrays,
#     816             columns,
#    (...)
#     819             typ=manager,
#     820         )
#     821     else:
# --> 822         mgr = ndarray_to_mgr(
#     823             data,
#     824             index,
#     825             columns,
#     826             dtype=dtype,
#     827             copy=copy,
#     828             typ=manager,
#     829         )
#     830 else:
#     831     mgr = dict_to_mgr(
#     832         {},
#     833         index,
#    (...)
#     836         typ=manager,
#     837     )
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\construction.py:319, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     314     values = _ensure_2d(values)
#     316 else:
#     317     # by definition an array here
#     318     # the dtypes will be coerced to a single dtype
# --> 319     values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#     321 if dtype is not None and values.dtype != dtype:
#     322     # GH#40110 see similar check inside sanitize_array
#     323     values = sanitize_array(
#     324         values,
#     325         None,
#    (...)
#     328         allow_2d=True,
#     329     )
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\construction.py:575, in _prep_ndarraylike(values, copy)
#     569 # we could have a 1-dim or 2-dim list here
#     570 # this is equiv of np.asarray, but does object conversion
#     571 # and platform dtype preservation
#     572 # does not convert e.g. [1, "a", True] to ["1", "a", "True"] like
#     573 #  np.asarray would
#     574 if is_list_like(values[0]):
# --> 575     values = np.array([convert(v) for v in values])
#     576 elif isinstance(values[0], np.ndarray) and values[0].ndim == 0:
#     577     # GH#21861 see test_constructor_list_of_lists
#     578     values = np.array([convert(v) for v in values])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (32,) + inhomogeneous part.

# %%
final_dict
# Out:
#                                                   0   \
# 0                     Database Core Fixed Income ...
#
#                                                   1   \
# 0                     Database Global Quality Val...
#
#                                                   2   \
# 0                     Database Strategic Fixed In...
#
#                                                   3   \
# 0                     Database U.S Small-Cap Core...
#
#                                                   4   \
# 0          Database       Core Fixed Income Compo...
#
#                                                   5   \
# 0          Database  Core Plus Fixed Income Compo...
#
#                                                   6   \
# 0          Database            Global Quality Val...
#
#                                                   7   \
# 0          Database         Strategic Fixed Incom...
#
#                                                   8   \
# 0          Database Strategic Fixed Income Opport...
#
#                                                   9   ...  \
# 0          Database     U.S Small-Cap Core Compos...  ...
#
#                                                   22  \
# 0        Database Core Fixed Income Composite (P7...
#
#                                                   23  \
# 0        Database Core Plus Fixed Income Composit...
#
#                                                   24  \
# 0        Database Strategic Fixed Income Composit...
#
#                                                   25  \
# 0        Database Strategic Fixed Income Opportun...
#
#                                                   26  \
# 0        Database               Core Fixed Income...
#
#                                                   27  \
# 0        Database          Core Plus Fixed Income...
#
#                                                   28  \
# 0        Database Global Quality Value Composite ...
#
#                                                   29  \
# 0        Database Strategic Fixed Income Composit...
#
#                                                   30  \
# 0        Database Strategic Fixed Income Opportun...
#
#                                                   31
# 0        Database             U.S Small-Cap Core ...
#
# [1 rows x 32 columns]

# %%
output_df
# Out:
#    Database             U.S Small-Cap Core Composite (P147285)
# 0  Wilshire  [● Priority 1: 12/2023, 07/2023, 12/2022, 11/2...

# %%
review_file = pd.merge(final_dict, output_df, on='Database', how='outer').groupby('Database').sum()
#elif output_df_ is not None:
        #final_dict_ = pd.DataFrame([final_dict_])
        #output_df_ = pd.DataFrame([output_df_])
#        review_file = pd.merge(final_dict_, output_df_, on='Database', how='outer').groupby('Database').sum()
    # Dropping unnecessary columns and replacing zero values with the description "No audit data generated":
review_file.columns = review_file.columns.str.rstrip("_x")
review_file = review_file.drop([x for x in review_file if x.endswith("_y")], axis = 1)
review_file = review_file.replace(0, "No audit data generated.", regex=True)
# Sorting column names and Database names:
review_file = review_file.reindex(sorted(review_file.columns), axis=1)
# Sorting index alphabetically (case insensitive):
review_file = review_file.reindex(index=(sorted(review_file.index, key=lambda s: s.lower())))
# Making sure index name doesn't get lost:
review_file.index.name = 'Database'
# Output path with respective name:
excel_output = r'C:\Users\l.arguello\Documents\Python Scripts\APX_automation_reports\output\data_auditor_review\DataAuditor_review_{}_APX.xlsx'.format(dataset)
# ********** excel_output = r'E:\Users\LauraMelissa\Downloads\apx\output\DataAuditor_review_{}_APX.xlsx'.format(dataset)
# Adding legend/keys table:
legend_dict = {'Priority 1': "",       
                }
legend_keys = pd.DataFrame([legend_dict])
legend_keys = legend_keys.set_axis(['Legend'], axis='index').transpose()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16372\1417306134.py in ?()
# ----> 1 review_file = pd.merge(final_dict, output_df, on='Database', how='outer').groupby('Database').sum()
#       2 #elif output_df_ is not None:
#       3         #final_dict_ = pd.DataFrame([final_dict_])
#       4         #output_df_ = pd.DataFrame([output_df_])
#
# c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
#     788             self.join_names,
#     789             left_drop,
#     790             right_drop,
# --> 791         ) = self._get_merge_keys()
#     792
#     793         if left_drop:
#     794             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1283                     if lk is not None:
#    1284                         # Then we're either Hashable or a wrong-length arraylike,
#    1285                         #  the latter of which will raise
#    1286                         lk = cast(Hashable, lk)
# -> 1287                         left_keys.append(left._get_label_or_level_values(lk))
#    1288                         join_names.append(lk)
#    1289                     else:
#    1290                         # work-around for merge_asof(left_index=True)
#
# c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'Database'

# %%
# Creating a for loop to assign dummy variables to the Data Gap Auditor report:
for n in range(0, excel_file.shape[1]):

    for i,j in enumerate(excel_file[excel_file.columns[(n)]]):
        
        
        try:
            if float(j) >= 0 or float(j) <= 0:

                excel_file[excel_file.columns[n]][i] = excel_file[excel_file.columns[n]][i].replace(j, '0') # "Complete"
                
        except:
            if "<NO APX> / " in j:
                excel_file[excel_file.columns[n]][i] = excel_file[excel_file.columns[n]][i].replace(j, '1') # "Data not in the Vault"
            elif " / <NO DATA>" in j:
                excel_file[excel_file.columns[n]][i] = excel_file[excel_file.columns[n]][i].replace(j, '2') # "Data not in the database"
            elif " / " in j:
                excel_file[excel_file.columns[n]][i] = excel_file[excel_file.columns[n]][i].replace(j, '3') # "Data not matching"  
            else:
                excel_file[excel_file.columns[n]][i] = excel_file[excel_file.columns[n]][i].replace(j, '')  # If the cell does not contain any of this criteria above, then it's not relevant for our analysis/reviewal

# %%
# Let's fill the NaN values for easier further processes:
excel_file.fillna('', inplace=True)

# %%
excel_file
# Out:
#         Taxable Accounts Taxable Assets Tax-Exempt Accounts Tax-Exempt Assets  \
# Date
# 12/2023                2              2                   2                 2
# 11/2023                2              2                   2                 2
# 10/2023                2              2                   2                 2
# 09/2023                0              0                   0                 0
# 08/2023                2              2                   2                 2
# 07/2023                2              2                   2                 2
# 06/2023                0              0                   0                 0
# 05/2023                2              2                   2                 2
# 04/2023                2              2                   2                 2
# 03/2023                3              3                   3                 3
# 02/2023                2              2                   2                 2
# 01/2023                2              2                   2                 2
# 12/2022                3              3                   3                 3
# 11/2022                2              2                   2                 2
# 10/2022                2              2                   2                 2
# 09/2022                3              3                   3                 3
#
#         Institutional or High Net Worth Separate Accounts  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                                                 0
# 08/2023
# 07/2023
# 06/2023                                                 0
# 05/2023
# 04/2023
# 03/2023                                                 1
# 02/2023
# 01/2023
# 12/2022                                                 1
# 11/2022
# 10/2022
# 09/2022                                                 1
#
#         Institutional or High Net Worth Separate Assets  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                                               0
# 08/2023
# 07/2023
# 06/2023                                               0
# 05/2023
# 04/2023
# 03/2023                                               1
# 02/2023
# 01/2023
# 12/2022                                               1
# 11/2022
# 10/2022
# 09/2022                                               1
#
#         Managed Account (WRAP) Accounts Managed Account (WRAP) Assets  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                               0                             0
# 08/2023
# 07/2023
# 06/2023                               0                             0
# 05/2023
# 04/2023
# 03/2023                               1                             1
# 02/2023
# 01/2023
# 12/2022                               1                             1
# 11/2022
# 10/2022
# 09/2022                               1                             1
#
#         Multiple Strategy Portfolio Accounts  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                                    0
# 08/2023
# 07/2023
# 06/2023                                    0
# 05/2023
# 04/2023
# 03/2023                                    1
# 02/2023
# 01/2023
# 12/2022                                    1
# 11/2022
# 10/2022
# 09/2022                                    1
#
#         Multiple Strategy Portfolio Assets  ... Other Assets Accounts Gained  \
# Date                                        ...
# 12/2023                                     ...
# 11/2023                                     ...
# 10/2023                                     ...
# 09/2023                                  0  ...            0
# 08/2023                                     ...
# 07/2023                                     ...
# 06/2023                                  0  ...            0
# 05/2023                                     ...
# 04/2023                                     ...
# 03/2023                                  1  ...            1
# 02/2023                                     ...
# 01/2023                                     ...
# 12/2022                                  1  ...            1               1
# 11/2022                                     ...
# 10/2022                                     ...
# 09/2022                                  1  ...            1               1
#
#         Assets Gained Accounts Lost Assets Lost  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                           3           3
# 08/2023
# 07/2023
# 06/2023                           0           0
# 05/2023
# 04/2023
# 03/2023
# 02/2023
# 01/2023
# 12/2022             1             1           1
# 11/2022
# 10/2022
# 09/2022             1             1           1
#
#         Median Tax-Exempt Account ($Millions)  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                                     1
# 08/2023
# 07/2023
# 06/2023                                     1
# 05/2023
# 04/2023
# 03/2023                                     1
# 02/2023
# 01/2023
# 12/2022                                     1
# 11/2022
# 10/2022
# 09/2022                                     1
#
#         Median Taxable Account ($Millions) Median Account ($Millions)  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                                  1                          1
# 08/2023
# 07/2023
# 06/2023                                  1                          1
# 05/2023
# 04/2023
# 03/2023                                  1                          1
# 02/2023
# 01/2023
# 12/2022                                  1                          1
# 11/2022
# 10/2022
# 09/2022                                  1                          1
#
#         Total Number of Clients $MM in Composite
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                       0                3
# 08/2023
# 07/2023
# 06/2023                       0                3
# 05/2023
# 04/2023
# 03/2023                       1                1
# 02/2023
# 01/2023
# 12/2022                       1                1
# 11/2022
# 10/2022
# 09/2022                       1
#
# [16 rows x 27 columns]

# %%
# Putting the dummy variables in a single column:
excel_file['Review'] = excel_file[excel_file.columns[0:]].apply(lambda x: ''.join(x.astype(str)), axis=1)
# Load a sample of how it looks like at the moment:
excel_file.head()
# Out:
#         Taxable Accounts Taxable Assets Tax-Exempt Accounts Tax-Exempt Assets  \
# Date
# 12/2023                2              2                   2                 2
# 11/2023                2              2                   2                 2
# 10/2023                2              2                   2                 2
# 09/2023                0              0                   0                 0
# 08/2023                2              2                   2                 2
#
#         Institutional or High Net Worth Separate Accounts  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                                                 0
# 08/2023
#
#         Institutional or High Net Worth Separate Assets  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                                               0
# 08/2023
#
#         Managed Account (WRAP) Accounts Managed Account (WRAP) Assets  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                               0                             0
# 08/2023
#
#         Multiple Strategy Portfolio Accounts  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                                    0
# 08/2023
#
#         Multiple Strategy Portfolio Assets  ... Accounts Gained Assets Gained  \
# Date                                        ...
# 12/2023                                     ...
# 11/2023                                     ...
# 10/2023                                     ...
# 09/2023                                  0  ...
# 08/2023                                     ...
#
#         Accounts Lost Assets Lost Median Tax-Exempt Account ($Millions)  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023             3           3                                     1
# 08/2023
#
#         Median Taxable Account ($Millions) Median Account ($Millions)  \
# Date
# 12/2023
# 11/2023
# 10/2023
# 09/2023                                  1                          1
# 08/2023
#
#         Total Number of Clients $MM in Composite                     Review
# Date
# 12/2023                                                                2222
# 11/2023                                                                2222
# 10/2023                                                                2222
# 09/2023                       0                3  0000000000000000003311103
# 08/2023                                                                2222
#
# [5 rows x 28 columns]

# %%
excel_file['Review']
# Out:
# Date
# 12/2023                           2222
# 11/2023                           2222
# 10/2023                           2222
# 09/2023      0000000000000000003311103
# 08/2023                           2222
# 07/2023                           2222
# 06/2023      0000000000000000000011103
# 05/2023                           2222
# 04/2023                           2222
# 03/2023        33331111111111111111111
# 02/2023                           2222
# 01/2023                           2222
# 12/2022    333311111111111111111111111
# 11/2022                           2222
# 10/2022                           2222
# 09/2022     33331111111111111111111111
# Name: Review, dtype: object

# %%
# Creating a for loop to assign the correct description to each period:
for i, j in enumerate(excel_file['Review']):
        
        if all('0' in k for k in j):
            excel_file['Review'][i] = excel_file['Review'][i].replace(j, 'Complete')

        elif all('1' in k for k in j):
            excel_file['Review'][i] = excel_file['Review'][i].replace(j, 'Data not in the Vault')

        elif all('2' in k for k in j):
            excel_file['Review'][i] = excel_file['Review'][i].replace(j, 'Data not in the database')   

        elif all('3' in k for k in j):
            excel_file['Review'][i] = excel_file['Review'][i].replace(j, 'Data not matching')

# %%
excel_file['Review']
# Out:
# Date
# 12/2023       Data not in the database
# 11/2023       Data not in the database
# 10/2023       Data not in the database
# 09/2023      0000000000000000003311103
# 08/2023       Data not in the database
# 07/2023       Data not in the database
# 06/2023      0000000000000000000011103
# 05/2023       Data not in the database
# 04/2023       Data not in the database
# 03/2023        33331111111111111111111
# 02/2023       Data not in the database
# 01/2023       Data not in the database
# 12/2022    333311111111111111111111111
# 11/2022       Data not in the database
# 10/2022       Data not in the database
# 09/2022     33331111111111111111111111
# Name: Review, dtype: object

# %%
# Now we need to continue to put the other conditions:
for i,j in enumerate(excel_file['Review']):

    if (any('1' in k for k in j) and any('0' in k for k in j)):
        excel_file['Review'][i] = excel_file['Review'][i].replace(j, 'Data not in the Vault')
    
    elif (any('2' in k for k in j) and any('0' in k for k in j)):
        excel_file['Review'][i] = excel_file['Review'][i].replace(j, 'Data not in the database')

    elif (any('3' in k for k in j) and any('0' in k for k in j)):
        excel_file['Review'][i] = excel_file['Review'][i].replace(j, 'Data not matching')

    elif (any('3' in k for k in j) and any('1' in k for k in j)):
        excel_file['Review'][i] = excel_file['Review'][i].replace(j, 'Data not in the Vault and not matching')
    
    elif (any('2' in k for k in j) and any('1' in k for k in j)):
        excel_file['Review'][i] = excel_file['Review'][i].replace(j, 'Data not in the Vault and not in the database')
    
    elif (any('3' in k for k in j) and any('2' in k for k in j) and any('1' in k for k in j)):
        excel_file['Review'][i] = excel_file['Review'][i].replace(j, 'Data not in the Vault, not matching and not in the database')

# %%
excel_file['Review']
# Out:
# Date
# 12/2023                  Data not in the database
# 11/2023                  Data not in the database
# 10/2023                  Data not in the database
# 09/2023                     Data not in the Vault
# 08/2023                  Data not in the database
# 07/2023                  Data not in the database
# 06/2023                     Data not in the Vault
# 05/2023                  Data not in the database
# 04/2023                  Data not in the database
# 03/2023    Data not in the Vault and not matching
# 02/2023                  Data not in the database
# 01/2023                  Data not in the database
# 12/2022    Data not in the Vault and not matching
# 11/2022                  Data not in the database
# 10/2022                  Data not in the database
# 09/2022    Data not in the Vault and not matching
# Name: Review, dtype: object

# %%
# Creating a list for each of the periods in the Review column:
periods_0 = []
periods_1 = []
periods_2 = []
periods_3 = []

for i,j in enumerate(zip(excel_file['Review'],excel_file.index)):

    if j[0] == 'Complete':
        periods_0.append(j[1])

    elif j[0] == 'Data not in the Vault':
        periods_1.append(j[1])
    
    elif j[0] == 'Data not in the database':
        periods_2.append(j[1])

    elif j[0] == 'Data not matching':
        periods_3.append(j[1])


#0 "Complete"
#1 "Data not in the Vault"
#2 "Data not in the database"
#3 "Data not matching"

# %%
# Sorting the lists by ascending order:
periods_0.sort()
periods_1.sort()
periods_2.sort()
periods_3.sort()

# %%
excel_file
# Out:
#         Corporate - Assets - Total Table  \
# Date
# 12/2023
# 09/2023                                1
# 06/2023                                1
# 03/2023                                1
# 12/2022                                1
# 09/2022                                1
#
#         Superannuation - Assets - Total Table  \
# Date
# 12/2023
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022                                     1
#
#         Public Fund (Gov) - Assets - Total Table  \
# Date
# 12/2023
# 09/2023                                        1
# 06/2023                                        1
# 03/2023                                        1
# 12/2022                                        1
# 09/2022                                        1
#
#         Union/Multi-Emp - Assets - Total Table  \
# Date
# 12/2023
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022                                      1
#
#         Found&Endow - Assets - Total Table Health Care - Assets - Total Table  \
# Date
# 12/2023
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022                                  1                                  1
#
#         Insurance - Assets - Total Table  \
# Date
# 12/2023
# 09/2023                                1
# 06/2023                                1
# 03/2023                                1
# 12/2022                                1
# 09/2022                                1
#
#         High Net Worth - Assets - Total Table  \
# Date
# 12/2023
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022                                     1
#
#         Wrap Accounts - Assets - Total Table  \
# Date
# 12/2023
# 09/2023
# 06/2023
# 03/2023                                    1
# 12/2022                                    1
# 09/2022                                    1
#
#         Sub-Advised - Assets - Total Table  ...  \
# Date                                        ...
# 12/2023                                     ...
# 09/2023                                  1  ...
# 06/2023                                  1  ...
# 03/2023                                  1  ...
# 12/2022                                  1  ...
# 09/2022                                  1  ...
#
#         Range - $10 Million - $100 Million  \
# Date
# 12/2023
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022
#
#         Total Assets in Range - $10 Million - $100 Million  \
# Date
# 12/2023
# 09/2023                                                  1
# 06/2023
# 03/2023                                                  1
# 12/2022                                                  1
# 09/2022                                                  1
#
#         Total Accounts in Range - $10 Million - $100 Million  \
# Date
# 12/2023
# 09/2023                                                  1
# 06/2023
# 03/2023                                                  1
# 12/2022                                                  1
# 09/2022                                                  1
#
#         Range - $100 Million - $500 Million  \
# Date
# 12/2023
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022
#
#         Total Assets in Range - $100 Million - $500 Million  \
# Date
# 12/2023
# 09/2023                                                  1
# 06/2023
# 03/2023                                                  1
# 12/2022                                                  1
# 09/2022                                                  1
#
#         Total Accounts in Range - $100 Million - $500 Million  \
# Date
# 12/2023
# 09/2023                                                  1
# 06/2023
# 03/2023                                                  1
# 12/2022                                                  1
# 09/2022                                                  1
#
#         Range - > $500 Million Total Assets in Range - > $500 Million  \
# Date
# 12/2023
# 09/2023                                                             1
# 06/2023
# 03/2023                                                             1
# 12/2022                                                             1
# 09/2022                                                             1
#
#         Total Accounts in Range - > $500 Million                 Review
# Date
# 12/2023                                                        Complete
# 09/2023                                        1  Data not in the Vault
# 06/2023                                           Data not in the Vault
# 03/2023                                        1  Data not in the Vault
# 12/2022                                        1  Data not in the Vault
# 09/2022                                        1  Data not in the Vault
#
# [6 rows x 213 columns]

# %% [markdown]
# #### **✨Output DataFrame:**

# %% [markdown]
# I'll be now creating a dictionary to compile the information and have the output as a dataframe by gathering the description found for the respective periods so that they can be inspected.

# %%
# Loading the first sheet "Table of Contents" to obtain information that can be input into the output dataframe:
excel_file_content = pd.read_excel(file_path+'/'+file_names[3])

# %%
# A description list is created to put in the final review without considering empty period lists:
description = []

if periods_1 := periods_1: description.append("✔ Data not in the Vault for the periods: {}".format((periods_1)).replace("'",'').replace('[','').replace(']',''))
if periods_2 := periods_2: description.append("✔ Data not in the database for the periods: {}".format((periods_2)).replace("'",'').replace('[','').replace(']',''))
if periods_3 := periods_3: description.append("✔ Data not matching for the periods: {}".format((periods_3)).replace("'",'').replace('[','').replace(']',''))

# %%
# Checking a sample of the final description:
description
# Out:
# ['✔ Data not in the Vault for the periods: 03/2023, 06/2023, 09/2022, 09/2023, 12/2022']

# %%
# Building the dictionary to then transform it into a dataframe:

dict = {'Database': excel_file_content.iloc[4][1],      # Database name e.g. "Wilshire"
        excel_file_orig.iloc[6][1]: description,                  # Product/vehicle name with description of findings e.g. "Core Fixed Income Composite (P73285)"
        }

# %%
# Creating a new dataframe that will sum up the findings in the Data Auditor:
output_df = pd.DataFrame([dict])

# %%
# Putting each description in a single line (this may duplicate the database name):
output_df0 = output_df.explode(excel_file_orig.iloc[6][1])

# Setting the column width to the max so the whole line can be read:
pd.set_option('display.max_colwidth', -1)

# Sample of the final review:
output_df0
# Out:
#         Database  \
# 0  Callan Assoc.
#
#                                                    Core Fixed Income Composite (P73285)
# 0  ✔ Data not in the Vault for the periods: 03/2023, 06/2023, 09/2022, 09/2023, 12/2022

# %% [markdown]
# ### Checking code for individual files

# %% [markdown]
# **APX**

# %%
# This script will generate an ouput Excel file for APX user.

# This Python code will review the original Data Gap Auditor files generated from the Vault, 
# and will sum up what has been found in those files.
# The code will work to create 2 separate Excel files and will loop through each dataset 
# to be worked on: AUM, Performance, Holdings, and Characteristics.

# The code will then work on that dataset and will create an output Excel file for for each user (APX and Client)
# that will contain a table summing up all the findings. It will also include
# all databases and the products/vehicles stated in the sheet_names variable.

# All the original files are put into the main folder: Manulife_DataAuditor, within it, 
# the folder contains four (4) folders for each dataset separately and within each, 
# the Data_Audit_Report Excel files for each database downloaded from the Vault
# Here's an example of main folder organization for this code: Manulife_DataAuditor/Performance/Data_Audit_Report_Alpha_Portfolio_Advisors_1_2024.xlsx

# Importing Python libraries that will be used:
import os
import glob 
import pandas as pd
from tqdm import tqdm
import time

import warnings
warnings.filterwarnings("ignore")

start_time = time.time()


# Setting dataset types:
datasets = ['AUM', 'Performance', 'Holdings', 'Characteristics']


print('Reviewing for the user: APX')

#for dataset in datasets:
# Vehicles that we're interested in are being listed here:
# Core Fixed Income	                    12776	P73285
# Core Plus Fixed Income	            12777	P74285 
# Global Quality Value	                12783	P85285
# Strategic Fixed Income	            12811	P121285
# Strategic Fixed Income Opportunities	12812	P126285
# US Small Cap Core	                    12823	P147285
sheet_names = ['P73285', 'P74285', 'P85285', 'P121285', 'P126285', 'P147285']
print('Checking dataset ')
# Setting file path. We'll be opening first the Performance folder:
absolute_path = "C:/Users/l.arguello/Downloads/Manulife_DataAuditor/"
# Full file path:
file_path = absolute_path + 'AUM'
# Using glob to get all the Excel file names in the selected folder, to loop through them:
csv_files = glob.glob(os.path.join(file_path, "[!~]*.xlsx")) # [!~] to ignore temporary/opened files
# Empty list to store file names from folder:
file_names = []
# Loop over the list of Excel files: 
for f in tqdm(csv_files, desc="Loading…",ascii=False, ncols=75):        
        time.sleep(0.03) 
        # Print the location and filename 
        print('File Name:', f.split("\\")[-1]) 
        # Add each Excel file name to file_names list 
        file_names.append(f.split("\\")[-1])      
print("Complete.")
# Out:
# Reviewing for the user: APX
# Checking dataset
# Loading…:   0%|                                     | 0/14 [00:00<?, ?it/s]
# Loading…:  29%|████████▎                    | 4/14 [00:00<00:00, 29.43it/s]
# File Name: Data_Audit_Report_Alpha_Portfolio_Advisors_1_2024.xlsx
# File Name: Data_Audit_Report_Broadridge_1_2024.xlsx
# File Name: Data_Audit_Report_Callan_Assoc_1_2024.xlsx
# File Name: Data_Audit_Report_Camradata_1_2024.xlsx
# File Name: Data_Audit_Report_eVestment_Alliance_1_2024.xlsx
# File Name: Data_Audit_Report_Global_Fund_Search_1_2024.xlsx
# Loading…:  50%|██████████████▌              | 7/14 [00:00<00:00, 28.89it/s]
# File Name: Data_Audit_Report_Global_Manager_Research_1_2024.xlsx
# File Name: Data_Audit_Report_Investment_Metrics_1_2024.xlsx
# File Name: Data_Audit_Report_LCG_Assoc_1_2024.xlsx
# Loading…:  71%|████████████████████        | 10/14 [00:00<00:00, 27.37it/s]
# File Name: Data_Audit_Report_Mercer_1_2024.xlsx
# File Name: Data_Audit_Report_Morningstar_1_2024.xlsx
# File Name: Data_Audit_Report_Preqin_Hedge_Fund_Analyst_1_2024.xlsx
# Loading…: 100%|████████████████████████████| 14/14 [00:00<00:00, 27.76it/s]
# File Name: Data_Audit_Report_PSN_Informa_1_2024.xlsx
# File Name: Data_Audit_Report_Wilshire_1_2024.xlsx
# Complete.

# %%
file_names
# Out:
# ['Data_Audit_Report_Alpha_Portfolio_Advisors_1_2024.xlsx',
#  'Data_Audit_Report_Broadridge_1_2024.xlsx',
#  'Data_Audit_Report_Callan_Assoc_1_2024.xlsx',
#  'Data_Audit_Report_Camradata_1_2024.xlsx',
#  'Data_Audit_Report_eVestment_Alliance_1_2024.xlsx',
#  'Data_Audit_Report_Global_Fund_Search_1_2024.xlsx',
#  'Data_Audit_Report_Global_Manager_Research_1_2024.xlsx',
#  'Data_Audit_Report_Investment_Metrics_1_2024.xlsx',
#  'Data_Audit_Report_LCG_Assoc_1_2024.xlsx',
#  'Data_Audit_Report_Mercer_1_2024.xlsx',
#  'Data_Audit_Report_Morningstar_1_2024.xlsx',
#  'Data_Audit_Report_Preqin_Hedge_Fund_Analyst_1_2024.xlsx',
#  'Data_Audit_Report_PSN_Informa_1_2024.xlsx',
#  'Data_Audit_Report_Wilshire_1_2024.xlsx']

# %%
sheet_names
# Out:
# ['P73285', 'P74285', 'P85285', 'P121285', 'P126285', 'P147285']

# %%
excel_file
# Out:
#         Corporate - Assets - Total Table Superannuation - Assets - Total Table Public Fund (Gov) - Assets - Total Table Union/Multi-Emp - Assets - Total Table Found&Endow - Assets - Total Table Health Care - Assets - Total Table Insurance - Assets - Total Table High Net Worth - Assets - Total Table Wrap Accounts - Assets - Total Table Sub-Advised - Assets - Total Table Supranationals - Assets - Total Table Sov Wealth Funds - Assets - Total Table Other - Assets - Total Table Calculated Total - Assets - Total Table Corporate - Accounts - Total Table Superannuation - Accounts - Total Table Public Fund (Gov) - Accounts - Total Table Union/Multi-Emp - Accounts - Total Table Found&Endow - Accounts - Total Table Health Care - Accounts - Total Table Insurance - Accounts - Total Table High Net Worth - Accounts - Total Table Wrap Accounts - Accounts - Total Table Sub-Advised - Accounts - Total Table Supranationals - Accounts - Total Table Sov Wealth Funds - Accounts - Total Table  \
# Date
# 12/2023                              NaN                                   NaN                                      NaN                                    NaN                                NaN                                NaN                              NaN                                   NaN                                  NaN                                NaN                                   NaN                                     NaN                          NaN                                     NaN                                NaN                                     NaN                                        NaN                                      NaN                                  NaN                                  NaN                                NaN                                     NaN                                    NaN                                  NaN                                     NaN                                       NaN
# 09/2023                     <NO APX> / $                                   NaN                             <NO APX> / $                                    NaN                                NaN                                NaN                     <NO APX> / $                                   NaN                                  NaN                      <NO APX> / $,                                   NaN                                     NaN                                                                                                                                             NaN                                                                                 NaN                                  NaN                                  NaN                                                                        NaN                                    NaN                                                                          NaN                                       NaN
# 06/2023                     <NO APX> / $                                   NaN                             <NO APX> / $                                    NaN                                NaN                                NaN                     <NO APX> / $                                   NaN                                  NaN                      <NO APX> / $,                                   NaN                                     NaN                                                                                                                                             NaN                                                                                 NaN                                  NaN                                  NaN                                                                        NaN                                    NaN                                                                          NaN                                       NaN
# 03/2023                     <NO APX> / $                                   NaN                             <NO APX> / $                                    NaN                                NaN                                NaN                     <NO APX> / $                                   NaN                         <NO APX> / $                      <NO APX> / $,                                   NaN                                     NaN                          NaN                           <NO APX> / $,                                                                        NaN                                                                                 NaN                                  NaN                                  NaN                                                                        NaN                                                                                                                 NaN                                       NaN
# 12/2022                     <NO APX> / $                                   NaN                             <NO APX> / $                                    NaN                                NaN                                NaN                     <NO APX> / $                                   NaN                         <NO APX> / $                      <NO APX> / $,                                   NaN                                     NaN                          NaN                           <NO APX> / $,                                                                        NaN                                                                                 NaN                                  NaN                                  NaN                                                                        NaN                                                                                                                 NaN                                       NaN
# 09/2022                     <NO APX> / $                          <NO APX> / $                             <NO APX> / $                           <NO APX> / $                       <NO APX> / $                       <NO APX> / $                     <NO APX> / $                          <NO APX> / $                         <NO APX> / $                      <NO APX> / $,                          <NO APX> / $                            <NO APX> / $                 <NO APX> / $                           <NO APX> / $,
#
#         Other - Accounts - Total Table Calculated Total - Accounts - Total Table Corporate - Assets - Taxable Table Superannuation - Assets - Taxable Table Public Fund (Gov) - Assets - Taxable Table Union/Multi-Emp - Assets - Taxable Table Found&Endow - Assets - Taxable Table Health Care - Assets - Taxable Table Insurance - Assets - Taxable Table High Net Worth - Assets - Taxable Table Wrap Accounts - Assets - Taxable Table Sub-Advised - Assets - Taxable Table Supranationals - Assets - Taxable Table Sov Wealth Funds - Assets - Taxable Table Other - Assets - Taxable Table Calculated Total - Assets - Taxable Table Corporate - Accounts - Taxable Table Superannuation - Accounts - Taxable Table Public Fund (Gov) - Accounts - Taxable Table Union/Multi-Emp - Accounts - Taxable Table Found&Endow - Accounts - Taxable Table Health Care - Accounts - Taxable Table Insurance - Accounts - Taxable Table High Net Worth - Accounts - Taxable Table Wrap Accounts - Accounts - Taxable Table  \
# Date
# 12/2023                            NaN                                       NaN                                NaN                                     NaN                                        NaN                                      NaN                                  NaN                                  NaN                                NaN                                     NaN                                    NaN                                  NaN                                     NaN                                       NaN                            NaN                                       NaN                                  NaN                                       NaN                                          NaN                                        NaN                                    NaN                                    NaN                                  NaN                                       NaN                                      NaN
# 09/2023                                                                                                         NaN                                     NaN                                        NaN                                      NaN                                  NaN                                  NaN                                                                        NaN                                    NaN                                                                          NaN                                       NaN                                                                                                           NaN                                       NaN                                          NaN                                        NaN                                    NaN                                    NaN                                                                            NaN                                      NaN
# 06/2023                                                                                                         NaN                                     NaN                                        NaN                                      NaN                                  NaN                                  NaN                                                                        NaN                                    NaN                                                                          NaN                                       NaN                                                                                                           NaN                                       NaN                                          NaN                                        NaN                                    NaN                                    NaN                                                                            NaN                                      NaN
# 03/2023                            NaN                                                                          NaN                                     NaN                                        NaN                                      NaN                                  NaN                                  NaN                       <NO APX> / $                                     NaN                           <NO APX> / $                        <NO APX> / $,                                     NaN                                       NaN                            NaN                             <NO APX> / $,                                  NaN                                       NaN                                          NaN                                        NaN                                    NaN                                    NaN                                                                            NaN
# 12/2022                            NaN                                                                          NaN                                     NaN                                        NaN                                      NaN                                  NaN                                  NaN                       <NO APX> / $                                     NaN                           <NO APX> / $                        <NO APX> / $,                                     NaN                                       NaN                            NaN                             <NO APX> / $,                                  NaN                                       NaN                                          NaN                                        NaN                                    NaN                                    NaN                                                                            NaN
# 09/2022                                                                                                <NO APX> / $                            <NO APX> / $                               <NO APX> / $                             <NO APX> / $                         <NO APX> / $                         <NO APX> / $                       <NO APX> / $                            <NO APX> / $                           <NO APX> / $                        <NO APX> / $,                            <NO APX> / $                              <NO APX> / $                   <NO APX> / $                             <NO APX> / $,
#
#         Sub-Advised - Accounts - Taxable Table Supranationals - Accounts - Taxable Table Sov Wealth Funds - Accounts - Taxable Table Other - Accounts - Taxable Table Calculated Total - Accounts - Taxable Table Corporate - Assets - Tax Exempt Table Superannuation - Assets - Tax Exempt Table Public Fund (Gov) - Assets - Tax Exempt Table Union/Multi-Emp - Assets - Tax Exempt Table Found&Endow - Assets - Tax Exempt Table Health Care - Assets - Tax Exempt Table Insurance - Assets - Tax Exempt Table High Net Worth - Assets - Tax Exempt Table Wrap Accounts - Assets - Tax Exempt Table Sub-Advised - Assets - Tax Exempt Table Supranationals - Assets - Tax Exempt Table Sov Wealth Funds - Assets - Tax Exempt Table Other - Assets - Tax Exempt Table Calculated Total - Assets - Tax Exempt Table Corporate - Accounts - Tax Exempt Table Superannuation - Accounts - Tax Exempt Table Public Fund (Gov) - Accounts - Tax Exempt Table Union/Multi-Emp - Accounts - Tax Exempt Table  \
# Date
# 12/2023                                    NaN                                       NaN                                         NaN                              NaN                                         NaN                                   NaN                                        NaN                                           NaN                                         NaN                                     NaN                                     NaN                                   NaN                                        NaN                                       NaN                                     NaN                                        NaN                                          NaN                               NaN                                          NaN                                     NaN                                          NaN                                             NaN                                           NaN
# 09/2023                                                                              NaN                                         NaN                                                                                                       <NO APX> / $                                        NaN                                  <NO APX> / $                                         NaN                                     NaN                                     NaN                                   NaN                                        NaN                                       NaN                            <NO APX> / $                                        NaN                                          NaN                               NaN                                                                                                                               NaN                                                                                           NaN
# 06/2023                                                                              NaN                                         NaN                                                                                                       <NO APX> / $                                        NaN                                  <NO APX> / $                                         NaN                                     NaN                                     NaN                                   NaN                                        NaN                                       NaN                            <NO APX> / $                                        NaN                                          NaN                               NaN                                                                                                                               NaN                                                                                           NaN
# 03/2023                                                                              NaN                                         NaN                              NaN                                                                      <NO APX> / $                                        NaN                                  <NO APX> / $                                         NaN                                     NaN                                     NaN                                   NaN                                        NaN                                       NaN                            <NO APX> / $                                        NaN                                          NaN                               NaN                                 <NO APX> / $                                                                                  NaN                                                                                           NaN
# 12/2022                                                                              NaN                                         NaN                              NaN                                                                      <NO APX> / $                                        NaN                                  <NO APX> / $                                         NaN                                     NaN                                     NaN                                   NaN                                        NaN                                       NaN                            <NO APX> / $                                        NaN                                          NaN                               NaN                                <NO APX> / $,                                                                                  NaN                                                                                           NaN
# 09/2022                                                                                                                                                                                                                                    <NO APX> / $                               <NO APX> / $                                  <NO APX> / $                                <NO APX> / $                            <NO APX> / $                            <NO APX> / $                          <NO APX> / $                               <NO APX> / $                              <NO APX> / $                            <NO APX> / $                               <NO APX> / $                                 <NO APX> / $                      <NO APX> / $                                 <NO APX> / $
#
#         Found&Endow - Accounts - Tax Exempt Table Health Care - Accounts - Tax Exempt Table Insurance - Accounts - Tax Exempt Table High Net Worth - Accounts - Tax Exempt Table Wrap Accounts - Accounts - Tax Exempt Table Sub-Advised - Accounts - Tax Exempt Table Supranationals - Accounts - Tax Exempt Table Sov Wealth Funds - Accounts - Tax Exempt Table Other - Accounts - Tax Exempt Table Calculated Total - Accounts - Tax Exempt Table Corporate - Assets - Institutional Table Superannuation - Assets - Institutional Table Public Fund (Gov) - Assets - Institutional Table Union/Multi-Emp - Assets - Institutional Table Found&Endow - Assets - Institutional Table Health Care - Assets - Institutional Table Insurance - Assets - Institutional Table High Net Worth - Assets - Institutional Table Wrap Accounts - Assets - Institutional Table Sub-Advised - Assets - Institutional Table Supranationals - Assets - Institutional Table Sov Wealth Funds - Assets - Institutional Table  \
# Date
# 12/2023                                       NaN                                       NaN                                     NaN                                          NaN                                         NaN                                       NaN                                          NaN                                            NaN                                 NaN                                            NaN                                      NaN                                           NaN                                              NaN                                            NaN                                        NaN                                        NaN                                      NaN                                           NaN                                          NaN                                        NaN                                           NaN                                             NaN
# 09/2023                                       NaN                                       NaN                                     NaN                                          NaN                                         NaN                                                                                    NaN                                            NaN                                 NaN                                                                            <NO APX> / $                                           NaN                                     <NO APX> / $                                            NaN                                        NaN                                        NaN                             <NO APX> / $                                           NaN                                          NaN                              <NO APX> / $,                                           NaN                                             NaN
# 06/2023                                       NaN                                       NaN                                     NaN                                          NaN                                         NaN                                                                                    NaN                                            NaN                                 NaN                                                                            <NO APX> / $                                           NaN                                     <NO APX> / $                                            NaN                                        NaN                                        NaN                             <NO APX> / $                                           NaN                                          NaN                              <NO APX> / $,                                           NaN                                             NaN
# 03/2023                                       NaN                                       NaN                                     NaN                                          NaN                                         NaN                                                                                    NaN                                            NaN                                 NaN                                                                            <NO APX> / $                                           NaN                                     <NO APX> / $                                            NaN                                        NaN                                        NaN                             <NO APX> / $                                           NaN                                          NaN                              <NO APX> / $,                                           NaN                                             NaN
# 12/2022                                       NaN                                       NaN                                     NaN                                          NaN                                         NaN                                                                                    NaN                                            NaN                                 NaN                                                                            <NO APX> / $                                           NaN                                     <NO APX> / $                                            NaN                                        NaN                                        NaN                             <NO APX> / $                                           NaN                                          NaN                              <NO APX> / $,                                           NaN                                             NaN
# 09/2022                                                                                                                                                                                                                                                                                                                                                                                                                                                                           <NO APX> / $                                  <NO APX> / $                                     <NO APX> / $                                   <NO APX> / $                               <NO APX> / $                               <NO APX> / $                             <NO APX> / $                                  <NO APX> / $                                 <NO APX> / $                              <NO APX> / $,                                  <NO APX> / $                                    <NO APX> / $
#
#         Other - Assets - Institutional Table Calculated Total - Assets - Institutional Table Corporate - Accounts - Institutional Table Superannuation - Accounts - Institutional Table Public Fund (Gov) - Accounts - Institutional Table Union/Multi-Emp - Accounts - Institutional Table Found&Endow - Accounts - Institutional Table Health Care - Accounts - Institutional Table Insurance - Accounts - Institutional Table High Net Worth - Accounts - Institutional Table Wrap Accounts - Accounts - Institutional Table Sub-Advised - Accounts - Institutional Table Supranationals - Accounts - Institutional Table Sov Wealth Funds - Accounts - Institutional Table Other - Accounts - Institutional Table Calculated Total - Accounts - Institutional Table Total Assets - Defined Contribution Table Taxable Assets - Defined Contribution Table Tax-Exempt Assets - Defined Contribution Table Institutional Assets - Defined Contribution Table Tax-Exempt Accounts - Defined Contribution Table  \
# Date
# 12/2023                                  NaN                                             NaN                                        NaN                                             NaN                                                NaN                                              NaN                                          NaN                                          NaN                                        NaN                                             NaN                                            NaN                                          NaN                                             NaN                                               NaN                                    NaN                                               NaN                                       NaN                                         NaN                                            NaN                                               NaN                                              NaN
# 09/2023                                  NaN                                                                                                                                        NaN                                                                                                 NaN                                          NaN                                          NaN                                                                                        NaN                                            NaN                                                                                          NaN                                               NaN                                    NaN                                                                                         NaN                                         NaN                                            NaN                                               NaN                                              NaN
# 06/2023                                  NaN                                            / $,                                                                                        NaN                                                                                                 NaN                                          NaN                                          NaN                                                                                        NaN                                            NaN                                                                                          NaN                                               NaN                                    NaN                                                                                         NaN                                         NaN                                            NaN                                               NaN                                              NaN
# 03/2023                                  NaN                                   <NO APX> / $,                                                                                        NaN                                                                                                 NaN                                          NaN                                          NaN                                                                                        NaN                                            NaN                                                                                          NaN                                               NaN                                    NaN                                                                                <NO APX> / $                                         NaN                                            NaN                                      <NO APX> / $
# 12/2022                                  NaN                                   <NO APX> / $,                                                                                        NaN                                                                                                 NaN                                          NaN                                          NaN                                                                                        NaN                                            NaN                                                                                          NaN                                               NaN                                    NaN                                                                                         NaN                                         NaN                                            NaN                                               NaN                                              NaN
# 09/2022                         <NO APX> / $                                   <NO APX> / $,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         <NO APX> / $                                <NO APX> / $                                   <NO APX> / $                                      <NO APX> / $
#
#         Institutional Accounts - Defined Contribution Table United States - Assets Table Canada - Assets Table United Kingdom - Assets Table Japan - Assets Table Australia - Assets Table Hong Kong - Assets Table Singapore - Assets Table Other Asia ex-Japan - Assets Table Africa/Middle East - Assets Table Latin America - Assets Table Other - Assets Table Europe ex-UK - Assets Table Denmark - Assets Table Eastern Europe - Assets Table Finland - Assets Table France - Assets Table Germany - Assets Table Italy - Assets Table Netherlands - Assets Table Norway - Assets Table Spain - Assets Table Sweden - Assets Table Switzerland - Assets Table Other Europe - Assets Table United States - Accounts Table Canada - Accounts Table United Kingdom - Accounts Table Japan - Accounts Table Australia - Accounts Table Hong Kong - Accounts Table Singapore - Accounts Table Other Asia ex-Japan - Accounts Table Africa/Middle East - Accounts Table Latin America - Accounts Table Other - Accounts Table  \
# Date
# 12/2023                                                NaN                           NaN                   NaN                           NaN                  NaN                      NaN                      NaN                      NaN                                NaN                               NaN                          NaN                  NaN                         NaN                    NaN                           NaN                    NaN                   NaN                    NaN                  NaN                        NaN                   NaN                  NaN                   NaN                        NaN                         NaN                            NaN                     NaN                             NaN                    NaN                        NaN                        NaN                        NaN                                  NaN                                 NaN                            NaN                    NaN
# 09/2023                                                NaN                 <NO APX> / $,                   NaN                           NaN                  NaN                      NaN             <NO APX> / $                      NaN                                NaN                               NaN                          NaN                  NaN                         NaN                    NaN                           NaN                    NaN                   NaN                    NaN                  NaN                        NaN                   NaN                  NaN                   NaN                        NaN                         NaN                                                    NaN                             NaN                    NaN                        NaN                                                   NaN                                  NaN                                 NaN                            NaN                    NaN
# 06/2023                                                NaN                           NaN                   NaN                           NaN                  NaN                      NaN                      NaN                      NaN                                NaN                               NaN                          NaN                  NaN                         NaN                    NaN                           NaN                    NaN                   NaN                    NaN                  NaN                        NaN                   NaN                  NaN                   NaN                        NaN                         NaN                            NaN                     NaN                             NaN                    NaN                        NaN                        NaN                        NaN                                  NaN                                 NaN                            NaN                    NaN
# 03/2023                                                NaN                 <NO APX> / $,                   NaN                           NaN                  NaN                      NaN             <NO APX> / $                      NaN                                NaN                               NaN                          NaN                  NaN                         NaN                    NaN                           NaN                    NaN                   NaN                    NaN                  NaN                        NaN                   NaN                  NaN                   NaN                        NaN                         NaN                                                    NaN                             NaN                    NaN                        NaN                                                   NaN                                  NaN                                 NaN                            NaN                    NaN
# 12/2022                                                NaN                 <NO APX> / $,                   NaN                           NaN                  NaN                      NaN             <NO APX> / $                      NaN                                NaN                               NaN                          NaN                  NaN                         NaN                    NaN                           NaN                    NaN                   NaN                    NaN                  NaN                        NaN                   NaN                  NaN                   NaN                        NaN                         NaN                                                    NaN                             NaN                    NaN                        NaN                                                   NaN                                  NaN                                 NaN                            NaN                    NaN
# 09/2022                                                                    <NO APX> / $,          <NO APX> / $                  <NO APX> / $         <NO APX> / $             <NO APX> / $             <NO APX> / $             <NO APX> / $                       <NO APX> / $                      <NO APX> / $                 <NO APX> / $         <NO APX> / $                <NO APX> / $           <NO APX> / $                  <NO APX> / $           <NO APX> / $          <NO APX> / $           <NO APX> / $         <NO APX> / $               <NO APX> / $          <NO APX> / $         <NO APX> / $          <NO APX> / $               <NO APX> / $                <NO APX> / $
#
#         Europe ex-UK - Accounts Table Denmark - Accounts Table Eastern Europe - Accounts Table Finland - Accounts Table France - Accounts Table Germany - Accounts Table Italy - Accounts Table Netherlands - Accounts Table Norway - Accounts Table Spain - Accounts Table Sweden - Accounts Table Switzerland - Accounts Table Other Europe - Accounts Table Total - Assets Table Separate Account - Assets Table Pooled/Commingled - Assets Table Mutual Fund Institutional - Assets Table Mutual Fund Retail - Assets Table Total - Accounts Table Separate Account - Accounts Table Pooled/Commingled - Accounts Table Mutual Fund Institutional - Accounts Table Mutual Fund Retail - Accounts Table Accounts - Gained Table Assets ($M) - Gained Table % Gained - Gained Table Accounts - Lost Table Assets ($M) - Lost Table % Lost - Lost Table Rank - Largest Client 1 Account Type - Largest Client 1 Aggregate Account Size - Largest Client 1 Rank - Largest Client 2 Account Type - Largest Client 2  \
# Date
# 12/2023                           NaN                      NaN                             NaN                      NaN                     NaN                      NaN                    NaN                          NaN                     NaN                    NaN                     NaN                          NaN                           NaN                  NaN                             NaN                              NaN                                      NaN                               NaN                    NaN                               NaN                                NaN                                        NaN                                 NaN                     NaN                        NaN                     NaN                   NaN                      NaN                 NaN                                                     NaN                                       NaN                                                     NaN
# 09/2023                           NaN                      NaN                             NaN                      NaN                     NaN                      NaN                    NaN                          NaN                     NaN                    NaN                     NaN                          NaN                           NaN                                                                                                                                                              NaN                                                                                                                                                                        NaN                     NaN                        NaN                     NaN                   NaN                      NaN                 NaN                                             Sub-Advised                                                                                       Sub-Advised
# 06/2023                           NaN                      NaN                             NaN                      NaN                     NaN                      NaN                    NaN                          NaN                     NaN                    NaN                     NaN                          NaN                           NaN                                                                                                                                                              NaN                                                                                                                                                                        NaN                     NaN                        NaN                     NaN                   NaN                      NaN                 NaN                                             Sub-Advised                                                                                       Sub-Advised
# 03/2023                           NaN                      NaN                             NaN                      NaN                     NaN                      NaN                    NaN                          NaN                     NaN                    NaN                     NaN                          NaN                           NaN        <NO APX> / $,                   <NO APX> / $,                     <NO APX> / $                            <NO APX> / $,                               NaN                                                                                                                                                                        NaN                                       <NO APX> / $                       %                                   <NO APX> / $                   %                                  <NO APX> / Sub-Advised                             <NO APX> / $,                                  <NO APX> / Sub-Advised
# 12/2022                           NaN                      NaN                             NaN                      NaN                     NaN                      NaN                    NaN                          NaN                     NaN                    NaN                     NaN                          NaN                           NaN        <NO APX> / $,                   <NO APX> / $,                     <NO APX> / $                                      NaN                               NaN                                                                                                                                    NaN                                 NaN                                       <NO APX> / $                       %                                   <NO APX> / $                   %                                  <NO APX> / Sub-Advised                             <NO APX> / $,                                  <NO APX> / Sub-Advised
# 09/2022                                                                                                                                                                                                                                                                                                                                                               <NO APX> / $,                   <NO APX> / $,                     <NO APX> / $                             <NO APX> / $                      <NO APX> / $                                                                                                                                                                                                                  <NO APX> / $                       %                                   <NO APX> / $                   %                                  <NO APX> / Sub-Advised                             <NO APX> / $,                                  <NO APX> / Sub-Advised
#
#         Aggregate Account Size - Largest Client 2 Rank - Largest Client 3 Account Type - Largest Client 3 Aggregate Account Size - Largest Client 3 Rank - Largest Client 4 Account Type - Largest Client 4 Aggregate Account Size - Largest Client 4 Rank - Largest Client 5 Account Type - Largest Client 5 Aggregate Account Size - Largest Client 5 Range - < $1 Million Total Assets in Range - < $1 Million Total Accounts in Range - < $1 Million Range - $1 Million - $10 Million Total Assets in Range - $1 Million - $10 Million Total Accounts in Range - $1 Million - $10 Million Range - $10 Million - $100 Million Total Assets in Range - $10 Million - $100 Million Total Accounts in Range - $10 Million - $100 Million Range - $100 Million - $500 Million Total Assets in Range - $100 Million - $500 Million Total Accounts in Range - $100 Million - $500 Million Range - > $500 Million Total Assets in Range - > $500 Million Total Accounts in Range - > $500 Million
# Date
# 12/2023                                       NaN                                                     NaN                                       NaN                                                     NaN                                       NaN                                                     NaN                                       NaN          < $ Million                                  NaN                                    NaN            $ Million - $ Million                                              NaN                                                NaN              $ Million - $ Million                                                NaN                                                NaN                 $ Million - $ Million                                                NaN                                                 NaN               > $ Million                                    NaN                                      NaN
# 09/2023                                                                      Public / Public (Government)                                                                                       Sub-Advised                                                                                         Corporate                                                    < $ Million                         <NO APX> / $                                                   $ Million - $ Million                                     <NO APX> / $                                                                 $ Million - $ Million                                       <NO APX> / $                                                                    $ Million - $ Million                                       <NO APX> / $                                                                   > $ Million                          <NO APX> / $,
# 06/2023                                                                      Public / Public (Government)                                                                                         Corporate                                                                                             Other                                                    < $ Million                                  NaN                                    NaN            $ Million - $ Million                                              NaN                                                NaN              $ Million - $ Million                                                NaN                                                NaN                 $ Million - $ Million                                                NaN                                                 NaN               > $ Million                                    NaN                                      NaN
# 03/2023                             <NO APX> / $,                          <NO APX> / Public (Government)                              <NO APX> / $                                    <NO APX> / Corporate                              <NO APX> / $                                 <NO APX> / Wrap Account                              <NO APX> / $          < $ Million                         <NO APX> / $                                                   $ Million - $ Million                                              NaN                                                NaN              $ Million - $ Million                                       <NO APX> / $                                                                    $ Million - $ Million                                       <NO APX> / $                                                                   > $ Million                          <NO APX> / $,
# 12/2022                             <NO APX> / $,                          <NO APX> / Public (Government)                              <NO APX> / $                                    <NO APX> / Corporate                              <NO APX> / $                                    <NO APX> / Corporate                              <NO APX> / $          < $ Million                         <NO APX> / $                                                   $ Million - $ Million                                              NaN                                                NaN              $ Million - $ Million                                       <NO APX> / $                                                                    $ Million - $ Million                                       <NO APX> / $                                                                   > $ Million                          <NO APX> / $,
# 09/2022                             <NO APX> / $,                          <NO APX> / Public (Government)                              <NO APX> / $                                    <NO APX> / Insurance                              <NO APX> / $                                  <NO APX> / Sub-Advised                              <NO APX> / $          < $ Million                         <NO APX> / $                                                   $ Million - $ Million                                     <NO APX> / $                                                                 $ Million - $ Million                                       <NO APX> / $                                                                    $ Million - $ Million                                       <NO APX> / $                                                                   > $ Million                          <NO APX> / $,

# %%
final_dict = []
nodata_ = [] 

excel_file = []

# For loop to select the Excel file:
for i in range(len(file_names)):
    print('Checking file name: ', file_names[i])
    # This variable will contain the first sheet in the Data Audtor (table of contents) which will be needed to fill information in the tables:
    excel_file_content = pd.read_excel(file_path+'/'+file_names[i]) 
    # For loop to select the sheet name (vehicle):
    for j in range(len(sheet_names)):
            try:
                # For loop to select the sheet name (vehicle):
                    # Will do a try and except since there are sheets that don't exist in the files, so the code doesn't crash:
                print('Checking sheet name: ', sheet_names[j])
                        # Defining the Excel file to be openned and the sheet we need from the book:
                excel_file_orig = pd.read_excel(file_path+'/'+file_names[i], sheet_name=sheet_names[j])
                    # If sheet is not found then let's try this so the code can continue:
            except:
    
                #print('No sheet found for the vehicle {}'.format(sheet_names[j]))
                dict_ = {'Database': excel_file_content.iloc[4][1],            # Database name e.g. "Wilshire"
                excel_file_orig.iloc[6][1]: "No audit data generated.",        # Product/vehicle name with description of findings e.g. "Core Fixed Income Composite (P73285)"
                    } 
                nodata_.append(dict_) # Adding the respective database and vehicle name that does not exist to list
                output_df_ = pd.DataFrame(nodata_).groupby(['Database']).sum() # Grouping dataframe by database
                continue
                # Selecting the header names placed in row 7 (row in which we start to have some relevant information to gather):
            excel_file_orig.rename(columns = excel_file_orig.iloc[7], inplace= True)
                # Selecting the rows with data and resetting the index:  
            excel_file = excel_file_orig[7:][1:].set_index(['Date'], drop=True)
                # Checking data type of all columns in the file:

                # Date column does not have the correct type, the others are mixed due to special characters being in them such as /
                # We need information from 09/2022 onwards, so I'll be turning Date column into correct type and then filter by date:
            excel_file.index = pd.to_datetime(excel_file.index)
                # Selecting data in the dataframe by the correct date:
            excel_file = excel_file[~(excel_file.index < '09/2022')]
                # Setting up the correct format for the index/Date column
            excel_file.index = excel_file.index.strftime("%m/%Y")
                # Dropping rows and columns in which all the cells contain NaN values:
            excel_file = excel_file.dropna(how='all', axis=0).dropna(how='all', axis=1) 

            
            for n in range(0, excel_file.shape[1]):
                     
                    for m,p in enumerate(excel_file[excel_file.columns[(n)]]):
                                                    
                            try:
                                if (int(float(p) >= 0)) or (int(float(p) <= 0)):
                                    excel_file[excel_file.columns[n]][m] = ''
                            except:
                                excel_file = excel_file.replace({r'(-?[0-9\.]+)\s*/ <NO DATA>': '1',     # Data not in database
                                                 r'<NO APX> \s*/ (-?[0-9\.]+)': '',                        # Data not in Vault
                                                 r'(-?[0-9\.]+)\s*/ (-?[0-9\.]+)': '',                     # Data not matching
                                                 r'(-?[0-9\.]+)': ''},                                     # Complete
                                                  regex=True) 
     

            excel_file.fillna('', inplace=True)
            excel_file['Review'] = excel_file[excel_file.columns[0:]].apply(lambda x: ''.join(x.astype(str)), axis=1


            for m,p in enumerate(excel_file)['Review']:
                    if (any('1' in k for k in p)):
                    excel_file['Review'][m] = excel_file['Review'][m].replace(p, 'Priority 1')  
                    else:  
                    excel_file['Review'][m] = excel_file['Review'][m].replace(p, 'No annotation')

                        #df_apx_list.append(df_apx[i])
        # This will check for the data is not in the database/vault/matching:
        #df_apx = df_apx.replace({r'(-?[0-9\.]+)\s*/ <NO DATA>': '1',     # Data not in database
        #                     r'<NO APX> \s*/ (-?[0-9\.]+)': '',                        # Data not in Vault
        #                     r'(-?[0-9\.]+)\s*/ (-?[0-9\.]+)': '',                     # Data not matching
        #                     r'(-?[0-9\.]+)': ''},                                     # Complete
        #                      regex=True)       
    
    # Let's fill the NaN values for easier further processes:
    #df_apx[i].fillna('', inplace=True)
    #df_apx_list.append(df_apx[i])
    # Putting the dummy variables in a single column named 'Review':
# Out:
# Checking file name:  Data_Audit_Report_Alpha_Portfolio_Advisors_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_Broadridge_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_Callan_Assoc_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_Camradata_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_eVestment_Alliance_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_Global_Fund_Search_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_Global_Manager_Research_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# Checking sheet name:  P85285
# Checking sheet name:  P121285
# Checking sheet name:  P126285
# Checking sheet name:  P147285
# Checking file name:  Data_Audit_Report_Investment_Metrics_1_2024.xlsx
# Checking sheet name:  P73285
# Checking sheet name:  P74285
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[217], line 51
#      50 try:
# ---> 51     if (int(float(p) >= 0)) or (int(float(p) <= 0)):
#      52         excel_file[excel_file.columns[n]][m] = ''
#
# ValueError: could not convert string to float: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[217], line 54
#      52                         excel_file[excel_file.columns[n]][m] = ''
#      53                 except:
# ---> 54                     excel_file = excel_file.replace({r'(-?[0-9\.]+)\s*/ <NO DATA>': '1',     # Data not in database
#      55                                      r'<NO APX> \s*/ (-?[0-9\.]+)': '',                        # Data not in Vault
#      56                                      r'(-?[0-9\.]+)\s*/ (-?[0-9\.]+)': '',                     # Data not matching
#      57                                      r'(-?[0-9\.]+)': ''},                                     # Complete
#      58                                       regex=True)
#      61 excel_file.fillna('', inplace=True)
#      62 excel_file['Review'] = excel_file[excel_file.columns[0:]].apply(lambda x: ''.join(x.astype(str)), axis=1)
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\generic.py:7819, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    7816     else:
#    7817         to_replace, value = keys, values
# -> 7819     return self.replace(
#    7820         to_replace, value, inplace=inplace, limit=limit, regex=regex
#    7821     )
#    7822 else:
#    7823     # need a non-zero len on all axes
#    7824     if not self.size:
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\generic.py:7867, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    7862     if len(to_replace) != len(value):
#    7863         raise ValueError(
#    7864             f"Replacement lists must match in length. "
#    7865             f"Expecting {len(to_replace)} got {len(value)} "
#    7866         )
# -> 7867     new_data = self._mgr.replace_list(
#    7868         src_list=to_replace,
#    7869         dest_list=value,
#    7870         inplace=inplace,
#    7871         regex=regex,
#    7872     )
#    7874 elif to_replace is None:
#    7875     if not (
#    7876         is_re_compilable(regex)
#    7877         or is_list_like(regex)
#    7878         or is_dict_like(regex)
#    7879     ):
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\base.py:253, in DataManager.replace_list(self, src_list, dest_list, inplace, regex)
#     250 """do a list replace"""
#     251 inplace = validate_bool_kwarg(inplace, "inplace")
# --> 253 bm = self.apply_with_block(
#     254     "replace_list",
#     255     src_list=src_list,
#     256     dest_list=dest_list,
#     257     inplace=inplace,
#     258     regex=regex,
#     259     using_cow=using_copy_on_write(),
#     260 )
#     261 bm._consolidate_inplace()
#     262 return bm
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:892, in Block.replace_list(self, src_list, dest_list, inplace, regex, using_cow)
#     887     m = mib[blk_num : blk_num + 1]
#     889 # error: Argument "mask" to "_replace_coerce" of "Block" has
#     890 # incompatible type "Union[ExtensionArray, ndarray[Any, Any], bool]";
#     891 # expected "ndarray[Any, dtype[bool_]]"
# --> 892 result = blk._replace_coerce(
#     893     to_replace=src,
#     894     value=dest,
#     895     mask=m,
#     896     inplace=inplace,
#     897     regex=regex,
#     898     using_cow=using_cow,
#     899 )
#     901 if using_cow and i != src_len:
#     902     # This is ugly, but we have to get rid of intermediate refs
#     903     # that did not go out of scope yet, otherwise we will trigger
#     904     # many unnecessary copies
#     905     for b in result:
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:955, in Block._replace_coerce(self, to_replace, value, mask, inplace, regex, using_cow)
#     933 """
#     934 Replace value corresponding to the given boolean array with another
#     935 value.
#    (...)
#     952 List[Block]
#     953 """
#     954 if should_use_regex(regex, to_replace):
# --> 955     return self._replace_regex(
#     956         to_replace,
#     957         value,
#     958         inplace=inplace,
#     959         mask=mask,
#     960     )
#     961 else:
#     962     if value is None:
#     963         # gh-45601, gh-45836, gh-46634
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:804, in Block._replace_regex(self, to_replace, value, inplace, mask, using_cow)
#     800     return [self] if inplace else [self.copy()]
#     802 rx = re.compile(to_replace)
# --> 804 block = self._maybe_copy(using_cow, inplace)
#     806 replace_regex(block.values, rx, value, mask)
#     808 return block.convert(copy=False, using_cow=using_cow)
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:660, in Block._maybe_copy(self, using_cow, inplace)
#     658     blk = self.copy(deep=deep)
#     659 else:
# --> 660     blk = self if inplace else self.copy()
#     661 return blk
#
# File c:\Users\l.arguello\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:645, in Block.copy(self, deep)
#     643 refs: BlockValuesRefs | None
#     644 if deep:
# --> 645     values = values.copy()
#     646     refs = None
#     647 else:
#
# KeyboardInterrupt:

# %%
for n in range(0, excel_file.shape[1]):
    for m,p in enumerate(excel_file[excel_file.columns[(n)]]):
        if (r'(-?[0-9\.]+)\s*/ <NO DATA>') in p:
            print('a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[224], line 3
#       1 for n in range(0, excel_file.shape[1]):
#       2     for m,p in enumerate(excel_file[excel_file.columns[(n)]]):
# ----> 3         if (r'(-?[0-9\.]+)\s*/ <NO DATA>') in p:
#       4             print('a')
#
# TypeError: argument of type 'float' is not iterable

# %%
excel_file
# Out:
#         Total Product Assets ($MM) Separate Account Assets ($MM) Commingled Account Assets ($MM) Mutual Fund - Institutional ($MM) Mutual Fund - Retail ($MM) Product Number of Accounts Accounts Gained Assets Gained From New Accounts Accounts Lost Assets Lost from Termintated Accounts Review
# Date
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022

# %%
df_apx_list[4]#.replace({r'(-?[0-9\.]+)\s*/ <NO DATA>': '4',     # Data not in database
              #              r'<NO APX> \s*/ (-?[0-9\.]+)': '',                        # Data not in Vault
              #              r'(-?[0-9\.]+)\s*/ (-?[0-9\.]+)': '',                     # Data not matching
              #              r'(-?[0-9\.]+)': '1'},                                     # Complete
              #               regex=True)
# Out:
#         Total Product Assets ($MM) Separate Account Assets ($MM) Commingled Account Assets ($MM) Mutual Fund - Institutional ($MM) Mutual Fund - Retail ($MM) Product Number of Accounts Accounts Gained Assets Gained From New Accounts Accounts Lost Assets Lost from Termintated Accounts
# Date
# 09/2023
# 06/2023
# 03/2023         <NO APX> / 1828.68            <NO APX> / 1798.67                <NO APX> / 30.02                                                                            <NO APX> / 5    <NO APX> / 2                 <NO APX> / 5.22  <NO APX> / 0                          <NO APX> / 0
# 12/2022         <NO APX> / 1690.89            <NO APX> / 1667.55                <NO APX> / 23.33                                                                            <NO APX> / 3    <NO APX> / 0                    <NO APX> / 0  <NO APX> / 0                          <NO APX> / 0
# 09/2022         <NO APX> / 1579.56            <NO APX> / 1557.44                <NO APX> / 22.12                      <NO APX> / 0               <NO APX> / 0               <NO APX> / 3    <NO APX> / 0                    <NO APX> / 0  <NO APX> / 0                          <NO APX> / 0

# %%
df_apx['Review'] = df_apx[df_apx.columns[0:]].apply(lambda x: ''.join(x.astype(str)), axis=1)
df_apx
# Out:
#         Total Product Assets ($MM) Separate Account Assets ($MM)  \
# Date
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022
#
#         Commingled Account Assets ($MM) Mutual Fund - Institutional ($MM)  \
# Date
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022
#
#         Mutual Fund - Retail ($MM) Product Number of Accounts Accounts Gained  \
# Date
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022
#
#         Assets Gained From New Accounts Accounts Lost  \
# Date
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022
#
#         Assets Lost from Termintated Accounts Review
# Date
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022

# %%
df_apx
# Out:
#         Total Product Assets ($MM) Separate Account Assets ($MM)  \
# Date
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022
#
#         Commingled Account Assets ($MM) Mutual Fund - Institutional ($MM)  \
# Date
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022
#
#         Mutual Fund - Retail ($MM) Product Number of Accounts Accounts Gained  \
# Date
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022
#
#         Assets Gained From New Accounts Accounts Lost  \
# Date
# 09/2023
# 06/2023
# 03/2023
# 12/2022
# 09/2022
#
#         Assets Lost from Termintated Accounts         Review
# Date
# 09/2023                                        No annotation
# 06/2023                                        No annotation
# 03/2023                                        No annotation
# 12/2022                                        No annotation
# 09/2022                                        No annotation

# %%
# For loop to select the Excel file:
for i in range(len(file_names)):
    print('Checking file name: ', file_names[i])
    # This variable will contain the first sheet in the Data Audtor (table of contents) which will be needed to fill information in the tables:
    excel_file_content = pd.read_excel(file_path+'/'+file_names[i]) 
    # For loop to select the sheet name (vehicle):
    for j in range(len(sheet_names)):
        # Creating a list for each of the periods in the Review column:
        periods_1 = []
        
        # A description list is created to put in the final review without considering empty period lists:
        description_apx = []
        
        # Gathering all the periods (month/year) for which each of these conditions stated above are present:
        for m,p in enumerate(zip(df_apx['Review'], df_apx.index)):                    
            if p[0] == 'Priority 1':
                periods_1.append(p[1])
            elif periods_1 == periods_1:
                description_apx.append("No annotation".format((list(set(periods_1)))).replace("'",'').replace('[','').replace(']',''))
        #0 "Complete"
        #1 "Data not in the database"
        #2 "Data not in the Vault"
        #3 "Data not matching"   
        
        
        if periods_1 := periods_1: description_apx.append("● Priority 1: {}\n".format((list(set(periods_1)))).replace("'",'').replace('[','').replace(']',''))
# Out:
# Checking file name:  Data_Audit_Report_Alpha_Portfolio_Advisors_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Broadridge_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Callan_Assoc_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Camradata_1_2024.xlsx
# Checking file name:  Data_Audit_Report_eVestment_Alliance_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Global_Fund_Search_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Global_Manager_Research_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Investment_Metrics_1_2024.xlsx
# Checking file name:  Data_Audit_Report_LCG_Assoc_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Mercer_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Morningstar_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Preqin_Hedge_Fund_Analyst_1_2024.xlsx
# Checking file name:  Data_Audit_Report_PSN_Informa_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Wilshire_1_2024.xlsx

# %%
description_apx
# Out:
# ['No annotation',
#  'No annotation',
#  'No annotation',
#  'No annotation',
#  'No annotation']

# %%
# For loop to select the Excel file:
for i in range(len(file_names)):
    print('Checking file name: ', file_names[i])
    # This variable will contain the first sheet in the Data Audtor (table of contents) which will be needed to fill information in the tables:
    excel_file_content = pd.read_excel(file_path+'/'+file_names[i]) 
    # For loop to select the sheet name (vehicle):
    for j in range(len(sheet_names)):
                                
                # Loading the first sheet "Table of Contents" to obtain information that can be input into the output dataframe:
                excel_file_content = pd.read_excel(file_path+'/'+file_names[i]) 

                # Building the dictionary that will contain the genetal information: database and description, to then transform it into a dataframe:
                dict = {'Database': excel_file_content.iloc[4][1],      # Database name e.g. "Wilshire"
                        excel_file_orig.iloc[6][1]: description_apx,        # Product/vehicle name with review description of findings e.g. "Core Fixed Income Composite (P73285)"
                        }  
                # Creating a new dataframe that will sum up the findings in the Data Auditor        
                output_df = pd.DataFrame([dict])

                # Putting each description in a single line (this may duplicate the database name):
                output_df0 = output_df.explode(excel_file_orig.iloc[6][1])

                # Final dict
                final_dict.append(output_df0)

                # Transforming into a dataframe the last dictionary with the review description:
                final_dict_ = pd.concat(final_dict) 

                # final_dict_ has a numerical index, whilst output_df_ has databases as its index, so we'll arrange that:
                final_dict_.set_index("Database",drop=True, inplace=True)
# Out:
# Checking file name:  Data_Audit_Report_Alpha_Portfolio_Advisors_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Broadridge_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Callan_Assoc_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Camradata_1_2024.xlsx
# Checking file name:  Data_Audit_Report_eVestment_Alliance_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Global_Fund_Search_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Global_Manager_Research_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Investment_Metrics_1_2024.xlsx
# Checking file name:  Data_Audit_Report_LCG_Assoc_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Mercer_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Morningstar_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Preqin_Hedge_Fund_Analyst_1_2024.xlsx
# Checking file name:  Data_Audit_Report_PSN_Informa_1_2024.xlsx
# Checking file name:  Data_Audit_Report_Wilshire_1_2024.xlsx

# %%
# For loop to select the Excel file:
for i in range(len(file_names)):
    print('Checking file name: ', file_names[i])
    # This variable will contain the first sheet in the Data Audtor (table of contents) which will be needed to fill information in the tables:
    excel_file_content = pd.read_excel(file_path+'/'+file_names[i]) 
    # For loop to select the sheet name (vehicle):
    for j in range(len(sheet_names)):
        print(output_df)
# Out:
# Checking file name:  Data_Audit_Report_Alpha_Portfolio_Advisors_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_Broadridge_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_Callan_Assoc_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_Camradata_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_eVestment_Alliance_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_Global_Fund_Search_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_Global_Manager_Research_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_Investment_Metrics_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_LCG_Assoc_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_Mercer_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_Morningstar_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_Preqin_Hedge_Fund_Analyst_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_PSN_Informa_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
# Checking file name:  Data_Audit_Report_Wilshire_1_2024.xlsx
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...
#    Database               Core Fixed Income Composite (P73285)
# 0  Wilshire  [No annotation, No annotation, No annotation, ...

# %%
final_dict_
# Out:
#                          U.S Small-Cap Core Composite (P147285)
# Database
# Alpha Portfolio Advisors                          No annotation
# Alpha Portfolio Advisors                          No annotation
# Alpha Portfolio Advisors                          No annotation
# Alpha Portfolio Advisors                          No annotation
# Alpha Portfolio Advisors                          No annotation
# ...                                                         ...
# Wilshire                                          No annotation
# Wilshire                                          No annotation
# Wilshire                                          No annotation
# Wilshire                                          No annotation
# Wilshire                                          No annotation
#
# [420 rows x 1 columns]

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
a = pd.DataFrame(output_df_)
a
# Out:
#                           Core Fixed Income Composite (P73285) Strategic Fixed Income Composite (P121285)             U.S Small-Cap Core Composite (P147285)
# Database
# Alpha Portfolio Advisors              No audit data generated.                   No audit data generated.                                                  0
# Broadridge                                                   0                                          0  No audit data generated.No audit data generate...
# Camradata                                                    0                                          0                           No audit data generated.
# Global Fund Search                                           0                                          0  No audit data generated.No audit data generate...
# Global Manager Research                                      0                                          0  No audit data generated.No audit data generate...
# Mercer                                                       0                                          0  No audit data generated.No audit data generate...
# Preqin Hedge Fund Analyst                                    0                                          0  No audit data generated.No audit data generate...
# eVestment Alliance                                           0                                          0  No audit data generated.No audit data generate...

# %%
a.groupby('Database')

# %%
# Joining these two tables together and grouping them by database:
review_file = pd.merge(final_dict_, output_df_, on='Database', how='outer').groupby('Database').sum()
review_file
# Out:
#                                       Core Fixed Income Composite (P73285)_x  \
# Database
# Alpha Portfolio Advisors   No annotationNo annotationNo annotation● Prior...
# Broadridge                 No annotationNo annotationNo annotation● Prior...
# Callan Assoc.              No annotationNo annotationNo annotation● Prior...
# Camradata                  No annotationNo annotationNo annotation● Prior...
# Global Fund Search         No annotationNo annotationNo annotation● Prior...
# Global Manager Research    No annotationNo annotationNo annotation● Prior...
# Investment Metrics         No annotationNo annotationNo annotation● Prior...
# LCG Assoc.                 No annotationNo annotationNo annotation● Prior...
# Mercer                     No annotationNo annotationNo annotation● Prior...
# Morningstar                No annotationNo annotationNo annotation● Prior...
# PSN Informa                No annotationNo annotationNo annotation● Prior...
# Preqin Hedge Fund Analyst  No annotationNo annotationNo annotation● Prior...
# Wilshire                   No annotationNo annotationNo annotation● Prior...
# eVestment Alliance         No annotationNo annotationNo annotation● Prior...
#
#                                       Core Fixed Income Composite (P73285)_y
# Database
# Alpha Portfolio Advisors                                                   0
# Broadridge                                                                 0
# Callan Assoc.                                                              0
# Camradata                                                                  0
# Global Fund Search                                                         0
# Global Manager Research                                                    0
# Investment Metrics         No audit data generated.No audit data generate...
# LCG Assoc.                                                                 0
# Mercer                                                                     0
# Morningstar                                                                0
# PSN Informa                                                                0
# Preqin Hedge Fund Analyst                                                  0
# Wilshire                                                                   0
# eVestment Alliance                                                         0

# %%
review_file
# Out:
#                                     U.S Small-Cap Core Composite (P147285)_x  \
# Database
# Alpha Portfolio Advisors                            No audit data generated.
# Broadridge                                          No audit data generated.
# Camradata                                           No audit data generated.
# Global Fund Search                                  No audit data generated.
# Global Manager Research                             No audit data generated.
# Mercer                                              No audit data generated.
# Preqin Hedge Fund Analyst                           No audit data generated.
# Wilshire                   No annotationNo annotationNo annotationNo anno...
# eVestment Alliance                                  No audit data generated.
#
#                           Core Fixed Income Composite (P73285)  \
# Database
# Alpha Portfolio Advisors              No audit data generated.
# Broadridge                            No audit data generated.
# Camradata                             No audit data generated.
# Global Fund Search                    No audit data generated.
# Global Manager Research               No audit data generated.
# Mercer                                No audit data generated.
# Preqin Hedge Fund Analyst             No audit data generated.
# Wilshire                              No audit data generated.
# eVestment Alliance                    No audit data generated.
#
#                           Strategic Fixed Income Composite (P121285)
# Database
# Alpha Portfolio Advisors                    No audit data generated.
# Broadridge                                  No audit data generated.
# Camradata                                   No audit data generated.
# Global Fund Search                          No audit data generated.
# Global Manager Research                     No audit data generated.
# Mercer                                      No audit data generated.
# Preqin Hedge Fund Analyst                   No audit data generated.
# Wilshire                                    No audit data generated.
# eVestment Alliance                          No audit data generated.

# %%
# Sorting column names and Database names:
review_file = review_file.reindex(sorted(review_file.columns), axis=1)
# Sorting index alphabetically (case insensitive):
review_file = review_file.reindex(index=(sorted(review_file.index, key=lambda s: s.lower())))
# Making sure index name doesn't get lost:
review_file.index.name = 'Database'
# Output path with respective name:
# excel_output = r'C:\Users\l.arguello\Documents\Python Scripts\APX_automation_reports\output\data_auditor_review\DataAuditor_review_{}_APX.xlsx'.format(dataset)

# Adding legend/keys table:
legend_dict = {'Priority 1': "" }
legend_keys = pd.DataFrame([legend_dict])
legend_keys = legend_keys.set_axis(['Legend'], axis='index').transpose()

# %%
review_file
# Out:
#                                       Core Fixed Income Composite (P73285)_x  \
# Database
# Alpha Portfolio Advisors   No annotationNo annotationNo annotation● Prior...
# Broadridge                 No annotationNo annotationNo annotation● Prior...
# Callan Assoc.              No annotationNo annotationNo annotation● Prior...
# Camradata                  No annotationNo annotationNo annotation● Prior...
# eVestment Alliance         No annotationNo annotationNo annotation● Prior...
# Global Fund Search         No annotationNo annotationNo annotation● Prior...
# Global Manager Research    No annotationNo annotationNo annotation● Prior...
# Investment Metrics         No annotationNo annotationNo annotation● Prior...
# LCG Assoc.                 No annotationNo annotationNo annotation● Prior...
# Mercer                     No annotationNo annotationNo annotation● Prior...
# Morningstar                No annotationNo annotationNo annotation● Prior...
# Preqin Hedge Fund Analyst  No annotationNo annotationNo annotation● Prior...
# PSN Informa                No annotationNo annotationNo annotation● Prior...
# Wilshire                   No annotationNo annotationNo annotation● Prior...
#
#                                       Core Fixed Income Composite (P73285)_y
# Database
# Alpha Portfolio Advisors                                                   0
# Broadridge                                                                 0
# Callan Assoc.                                                              0
# Camradata                                                                  0
# eVestment Alliance                                                         0
# Global Fund Search                                                         0
# Global Manager Research                                                    0
# Investment Metrics         No audit data generated.No audit data generate...
# LCG Assoc.                                                                 0
# Mercer                                                                     0
# Morningstar                                                                0
# Preqin Hedge Fund Analyst                                                  0
# PSN Informa                                                                0
# Wilshire                                                                   0

# %%
# ___________________________________________________________ Data to add in chart ________________________________________________________________
            ## Using this for loop to gather data for the APX file review:
            #                    
            #for n in range(0, excel_file.shape[1]):
            #
            #    for m,p in enumerate(excel_file[excel_file.columns[(n)]]):
            #    
            #        # Avoiding code crashes using try/except:    
            #        try:
            #            if float(p) >= 0 or float(p) <= 0:
            #            
            #                excel_file[excel_file.columns[n]][m] = excel_file[excel_file.columns[n]][m].replace(p, '0') # "Complete"

            #        except:
            #            if " / <NO DATA>" in p:
            #                excel_file[excel_file.columns[n]][m] = excel_file[excel_file.columns[n]][m].replace(p, '1') # "Data not in the database"
            #            elif "<NO APX> / " in p:
            #                excel_file[excel_file.columns[n]][m] = excel_file[excel_file.columns[n]][m].replace(p, '2') # "Data not in the Vault" 
            #            elif " / " in p:
            #                excel_file[excel_file.columns[n]][m] = excel_file[excel_file.columns[n]][m].replace(p, '3') # "Data not matching"
            #            else:
            #                excel_file[excel_file.columns[n]][m] = excel_file[excel_file.columns[n]][m].replace(p, '')  # If the cell does not contaelevant for our analysis/reviewal
# _______________________________________________________________ Data to add in chart ________________________________________________________________

    with pd.ExcelWriter(excel_output, engine="xlsxwriter") as writer:
        writer.book.formats[0].set_text_wrap()  # Update global format with text_wrap
        legend_keys.to_excel(writer, startrow = 1, startcol = 1) # Export to Excel file
        review_file.to_excel(writer, startrow = 6, startcol = 1)     
    # ////////////////////////////////////////////////////////////////////////////////
    # //////////////////////////////////Extra Steps//////////////////////////////////
    # //////////////////////////////////////////////////////////////////////////////        
    ## Accessing the Pandas file and sheet to add plot:
        # Loading worksheet for some formatting:
        worksheet = writer.sheets['Sheet1']
        # Set border color for tables and set vertical alignment of text:
        file_format = writer.book.add_format()
        file_format.set_text_wrap(True)
        file_format.set_border_color('#A6A6A6')
        file_format.set_align('left')
        file_format.set_valign('vcenter')
        for col_num, value in enumerate(review_file.columns.values):    
            header_format = writer.book.add_format({'bold':True, 'fg_color': '#F2F2F2', 'border_color':'black'})
            worksheet.write(6, col_num+2, value, header_format) # Set header format in soft gray color
        worksheet.set_column('B:H', 19.86, file_format)  # Set size of column (19.86 pixels     
        # Formatting cells:
        # Create a format to use in a merged range
        merge_format1 = writer.book.add_format(
            {
                "bold": 1,
                "border": 1,
                "align": "center",
                "valign": "vcenter",
                "fg_color": "#FCE4D6",
            })
        merge_format2 = writer.book.add_format(
            {
                "border": 1,
                "align": "left",
                "valign": "vcenter",
            })
    
        worksheet.merge_range("C2:F2", "Legend", merge_format1)
        worksheet.merge_range("C3:F3", "Data not in the database // APX needs to distribute this data", merge_format2)       
        
        writer.close()
# This is just the time the process took to complete per dataset
timetaken = (time.time() - start_time)/60
print("Task completed in %.2f minutes" % timetaken)
