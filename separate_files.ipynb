# %%
import pandas as pd

# %%
file_dir1 = 'C:/Users/l.arguello/Documents/Python Scripts/APX_automation_reports/Lord Abbett Short Duration Core APX_Breakdowns_3Q2018-3Q2022.xlsx'
file_dir2 = 'C:/Users/l.arguello/Documents/Python Scripts/APX_automation_reports/Lord Abbett Short Duration Core APX_Characteristics_3Q2018-3Q2022.xlsx'

# %%
df1 = pd.read_excel(file_dir1)
df2 = pd.read_excel(file_dir2)
df1.head()
# Out:
#   APX Code  ACCOUNT_NUMBER   END_DATE  \
# 0   P70259            5061 2018-09-28
# 1   P70259            5061 2018-09-28
# 2   P70259            5061 2018-09-28
# 3   P70259            5061 2018-09-28
# 4   P70259            5061 2018-09-28
#
#                                       DESCRIPTION  \
# 0  APX - Country Contribution by Sector Breakdown
# 1  APX - Country Contribution by Sector Breakdown
# 2  APX - Country Contribution by Sector Breakdown
# 3  APX - Country Contribution by Sector Breakdown
# 4  APX - Country Contribution by Sector Breakdown
#
#                                   SRC_LABEL VALUE_NUM
# 0                   Agency;Emerging Markets    (null)
# 1                   Agency;Non-US Developed    (null)
# 2                               Agency;U.S.    1.7822
# 3  Asset Backed Securities;Emerging Markets    (null)
# 4  Asset Backed Securities;Non-US Developed   2.37012

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5310 entries, 0 to 5309
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   APX Code        5310 non-null   object
#  1   ACCOUNT_NUMBER  5310 non-null   int64
#  2   END_DATE        5310 non-null   datetime64[ns]
#  3   DESCRIPTION     5310 non-null   object
#  4   SRC_LABEL       5310 non-null   object
#  5   VALUE_NUM       5310 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 249.0+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DESCRIPTION   367 non-null    object
#  1   END_DATE      367 non-null    datetime64[ns]
#  2   NUM_VALUE     367 non-null    object
#  3   LA Account #  367 non-null    int64
#  4   APX Code      367 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 14.5+ KB

# %%
print(df1.END_DATE.dt.year.min())
print(df1.END_DATE.dt.year.max())
print(df1.END_DATE.dt.month.min())
print(df1.END_DATE.dt.month.max())
print(df1.END_DATE.dt.day.min())
print(df1.END_DATE.dt.day.max())
print("_____")

print(df2.END_DATE.dt.year.min())
print(df2.END_DATE.dt.year.max())
print(df2.END_DATE.dt.month.min())
print(df2.END_DATE.dt.month.max())
print(df2.END_DATE.dt.day.min())
print(df2.END_DATE.dt.day.max())
# Out:
# 2018
# 2022
# 3
# 12
# 28
# 31
# ___________________
# 2018
# 2022
# 3
# 12
# 28
# 31

# %%
year+1
# Out:
# 2020

# %%
year = 2019

months = 3, 6, 9, 12

dfs = []

if year == 2018:
    for i in months:
        # Take the year
        date = str(year)+'-'+str(i).zfill(2)
        
        df3 = df1[df1['END_DATE'].dt.strftime('%Y-%m') == date]
        df3.to_excel("filter_output/Lord Abbett Short Duration Core APX_Characteristics_" + date + ".xlsx")
        dfs.append(df3)

        df3 = df2[df2['END_DATE'].dt.strftime('%Y-%m') == date]
        df3.to_excel("filter_output/Lord Abbett Short Duration Core APX_Breakdowns_" + date + ".xlsx")
        dfs.append(df3)

# %%
date = '2018-09'
df3 = df1[df1['END_DATE'].dt.strftime('%Y-%m') == date]
df3
# Out:
#     APX Code  ACCOUNT_NUMBER   END_DATE  \
# 0     P70259            5061 2018-09-28
# 1     P70259            5061 2018-09-28
# 2     P70259            5061 2018-09-28
# 3     P70259            5061 2018-09-28
# 4     P70259            5061 2018-09-28
# ..       ...             ...        ...
# 305   P70259            5061 2018-09-28
# 306   P70259            5061 2018-09-28
# 307   P70259            5061 2018-09-28
# 308   P70259            5061 2018-09-28
# 309   P70259            5061 2018-09-28
#
#                                         DESCRIPTION  \
# 0    APX - Country Contribution by Sector Breakdown
# 1    APX - Country Contribution by Sector Breakdown
# 2    APX - Country Contribution by Sector Breakdown
# 3    APX - Country Contribution by Sector Breakdown
# 4    APX - Country Contribution by Sector Breakdown
# ..                                              ...
# 305                          APX - Coupon Breakdown
# 306                          APX - Coupon Breakdown
# ...

# %%
date = '2018-12'
df3 = df1[df1['END_DATE'].dt.strftime('%Y-%m') == date]
df3.to_excel("filter_output/Lord Abbett Short Duration Core APX_Characteristics_" + date + ".xlsx")
df3
# Out:
# Empty DataFrame
# Columns: [APX Code, ACCOUNT_NUMBER, END_DATE, DESCRIPTION, SRC_LABEL, VALUE_NUM]
# Index: []

# %%
date = '2022-12'
df3 = df1[df1['END_DATE'].dt.strftime('%Y-%m') == date]
df3.to_excel("filter_output/Lord Abbett Short Duration Core APX_Characteristics_" + date + ".xlsx")
df3

# %%
for i in df1['END_DATE']:
    print(i)
# Out:
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# 2018-09-28 00:00:00
# ...
